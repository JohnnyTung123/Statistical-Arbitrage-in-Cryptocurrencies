# %% [markdown]
# ### Pairs Trading - Correlation
#
# **Motivation:**
# - Security A - (Something Correlated to it) is more mean-reverting. Similar securties should trade similarily. Hence, any discrepancies between the correlated pairs should converge
# - When there is a discrepancy, we form a long-short spread trade and bet on the discrepancy converging
# - Pairs trading is one of the most popular statistical arbitrage strategies in traditional markets. We want to test the performance of this strategy in the cryptocurrency market, as it is still relatively new and should be fertile grounds for finding market inefficiencies
# - While cointegration is a robust statistical method for identifying long-term relationships, Correlation is simpler and more responsive to short-term relationships, making it suitable for the fast-moving cryptocurrency market.

# %%
from datetime import datetime
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from itertools import combinations

# %% [markdown]
# ### Data
# We selected the top 1,000 currencies sorted by volume from CoinGecko. Then, we filtered out coins with fewer than 90% of daily price data points between 2018 and 2024.

# %%
from_pickle = pd.read_pickle('../Data/CoinGecko_px_vol_1D.pkl')

# %%
price_columns = [col for col in from_pickle.columns if 'price' in col]
crypto_px = from_pickle[price_columns]
crypto_px.columns = crypto_px.columns.droplevel(1)

# %%
crypto_px = crypto_px.loc['2018-01-01':]
crypto_px = crypto_px.drop(columns=['TUSD', 'DAI', 'WBTC', 'WETH', 'USDC', 'BSV'])

# %%
# Calculate the total number of data points
total_data_points = len(crypto_px)

# Calculate the number of non-NA/null entries for each coin
non_null_counts = crypto_px.notnull().sum()

# Calculate the threshold for 90% of the data points
threshold = 0.90 * total_data_points

# Filter out columns with fewer than 90% of data points
crypto_px = crypto_px.loc[:, non_null_counts >= threshold]

crypto_px
# Out:
#                      BTC       XRP         BNB      DOGE       ADA       TRX  \
# Date
# 2018-01-01  14093.606831  2.310120    8.828099  0.009091  0.747140  0.051654
# 2018-01-02  15321.932852  2.455290    9.090393  0.009335  0.807430  0.080893
# 2018-01-03  15583.885538  3.125710    9.886323  0.009592  1.075401  0.098107
# 2018-01-04  15976.365194  3.220050    9.675758  0.010098  1.179347  0.218139
# 2018-01-05  18336.922980  2.931380   16.488523  0.013841  1.077821  0.231673
# ...                  ...       ...         ...       ...       ...       ...
# 2024-08-12  58804.234500  0.552884  503.472306  0.100570  0.328140  0.127716
# 2024-08-13  59350.074333  0.568612  518.752217  0.107647  0.338874  0.126661
# 2024-08-14  60601.223178  0.576440  523.553455  0.106469  0.340317  0.128873
# 2024-08-15  58739.193822  0.568488  523.842262  0.102529  0.335251  0.130504
# 2024-08-16  57624.116929  0.561137  519.989791  0.100275  0.325393  0.130136
#
#                    LTC       LINK          BCH        EOS  ...       UTK  \
# Date                                                       ...
# 2018-01-01  230.462120   0.751033  2426.970077   7.672278  ...  0.467207
# 2018-01-02  255.048185   0.689388  2627.026940   9.504036  ...  0.647065
# 2018-01-03  248.042194   0.704623  2630.511811  10.090184  ...  0.896774
# 2018-01-04  244.834372   1.036826  2458.894372  11.713284  ...  0.874131
# 2018-01-05  254.138525   0.996575  2551.321685   9.673192  ...  0.762206
# ...                ...        ...          ...        ...  ...       ...
# 2024-08-12   59.691360  10.012537   330.440521   0.467477  ...  0.038229
# 2024-08-13   61.414267  10.561648   354.155288   0.500104  ...  0.039951
# 2024-08-14   63.411783  10.577495   352.234629   0.507208  ...  0.039211
# 2024-08-15   63.906408  10.396984   338.005714   0.506509  ...  0.037562
# 2024-08-16   65.236601  10.171003   334.436579   0.490075  ...  0.034784
#
#                  PIVX       SYS       REQ       FUN       VIB      NULS  \
# Date
# 2018-01-01  10.689500  0.783623  0.867352  0.086325  0.455327  2.267259
# 2018-01-02  11.555000  0.817777  0.809224  0.088933  0.464458  2.510494
# 2018-01-03  10.923600  0.798803  0.795348  0.106564  0.584170  3.696732
# 2018-01-04  10.581200  0.784280  0.826834  0.178514  0.698240  4.788923
# 2018-01-05   9.951170  0.748309  0.761799  0.161191  0.585847  5.659994
# ...               ...       ...       ...       ...       ...       ...
# 2024-08-12   0.193892  0.073564  0.090949  0.003115  0.057157  0.245821
# 2024-08-13   0.204125  0.078151  0.094758  0.003233  0.058272  0.255234
# 2024-08-14   0.203198  0.076065  0.094747  0.003273  0.058356  0.251570
# 2024-08-15   0.198953  0.073143  0.093194  0.003204  0.057466  0.247779
# 2024-08-16   0.179495  0.069979  0.090133  0.003019  0.056720  0.226651
#
#                 IDEX       MDT      BORG
# Date
# 2018-01-01       NaN       NaN       NaN
# 2018-01-02       NaN       NaN       NaN
# 2018-01-03       NaN       NaN       NaN
# 2018-01-04       NaN       NaN       NaN
# 2018-01-05       NaN       NaN       NaN
# ...              ...       ...       ...
# 2024-08-12  0.032078  0.036722  0.170774
# 2024-08-13  0.033471  0.038736  0.168182
# 2024-08-14  0.033162  0.038288  0.171173
# 2024-08-15  0.031942  0.038439  0.165207
# 2024-08-16  0.029790  0.036554  0.159102
#
# [2568 rows x 86 columns]

# %% [markdown]
# We have 86 coins and will select pairs from among them.

# %%
coins_ret = crypto_px / crypto_px.shift() - 1

# %%
def compute_turnover(port):
    to = (port.fillna(0)-port.shift().fillna(0)).abs().sum(1)   
    return to

# %%
def compute_sharpe_ratio(rets):
    mean_rets = rets.mean()*252
    vol = rets.std()*np.sqrt(252)
    sharpe_ratio = mean_rets / vol
    return sharpe_ratio

# %%
def compute_stats(rets):
    stats={}
    stats['avg'] = rets.mean()*252
    stats['vol'] = rets.std()*np.sqrt(252)
    stats['sharpe'] = stats['avg']/stats['vol']
    stats['hit_rate'] = rets[rets>0].count() / rets.count()
    stats = pd.DataFrame(stats)
    return stats

# %%
# def drawdown(px):
#     return (px / (px.expanding(min_periods=1).max()) - 1)
def drawdown(returns):
    """
    Calculate the drawdown series from the return series.
    
    Parameters:
    - returns: Series of returns (e.g., daily returns) for the strategy.
    
    Returns:
    - drawdown: Series of drawdowns over time.
    """
    # Calculate cumulative returns
    cumulative = (1 + returns).cumprod()

    # Calculate the running maximum
    running_max = cumulative.cummax()

    # Calculate drawdown
    drawdown = (cumulative - running_max) / running_max

    return drawdown

# %%
def duration(px):
    peak = px.expanding(min_periods=1).max()
    res = pd.DataFrame(index=px.index,columns=px.columns)
    for col in px.columns:
        for dt in px.index:
            if px.loc[dt,col] >= peak.loc[dt,col]:
                 res.loc[dt,col] = 0
            else: 
                res.loc[dt,col] = res.loc[:dt,col].iloc[-2] + 1
    return res

# %%
def final_results(avg_return, volatility, sharpe, hit_rate, max_drawdown, max_duration, holding_period, IR):
    stats = {}
    stats['Return (Ann.)'] = f"{(avg_return * 100):.2f}%"  
    stats['Volatility (Ann.)'] = f"{(volatility * 100):.2f}%"  
    stats['Sharpe Ratio'] = f"{sharpe:.2f}"  
    stats['Hit Rate'] = f"{(hit_rate * 100):.2f}%"  
    stats['Max Drawdown'] = f"{(max_drawdown):.2f}%"  
    stats['Max Duration'] = f"{max_duration:.2f} days"  
    stats['Holding Period'] = f"{holding_period:.2f} days"  
    stats['Information Ratio'] = f"{IR:.2f}" 

    stats_df = pd.DataFrame(stats, index=['Correlation']).T  
    return stats_df

# %% [markdown]
# ### Pairs Selection
#
# Pairs are selected and updated every 3 months to adapt to the fast-paced cryptocurrency market:
#
# - **Rolling Correlation**: Every six months, compute the rolling correlation of the log prices for each pair of assets over the past 2 year:
#
#   $$
#   \text{corr}(\log(p_{i,t}), \log(p_{j,t}))
#   $$
#
# - **Selection Criteria**: For each coin $i$, select the top $n$ pairs with the highest absolute correlation values, provided:
#
#   $$
#   |\text{corr}(p_{i,t}, p_{j,t})| \geq 0.9
#   $$

# %%
def select_pairs(crypto_px, top_n=5, corr_threshold=0.9):
    """
    Compute correlation for all pairs, select the top `n` correlated pairs for each coin
    with absolute correlation >= `corr_threshold`, and display the results along with the update date.
    
    Parameters:
    crypto_px (DataFrame): DataFrame containing price data of assets.
    top_n (int): The number of top pairs to select for each coin.
    corr_threshold (float): The threshold for absolute correlation to consider a pair.

    Returns:
    list: A sorted list of unique correlated pairs.
    """
    # Compute the correlation matrix
    corr_matrix = crypto_px.corr()

    # Initialize a set to store unique pairs
    final_pairs_set = set()

    # Initialize a dictionary to store top pairs for each coin
    top_pairs_per_coin = {}

    # Iterate over each coin in the correlation matrix
    for coin in corr_matrix.columns:
        # Sort the pairs by the absolute value of the correlation (higher absolute correlation is better)
        sorted_pairs = corr_matrix[coin].sort_values(ascending=False, key=abs)
        
        # Filter pairs with absolute correlation >= corr_threshold and exclude the coin itself
        filtered_pairs = sorted_pairs[(sorted_pairs.abs() >= corr_threshold) & (sorted_pairs.index != coin)]
        
        # Select the top `n` pairs for this coin
        top_pairs = filtered_pairs.head(top_n)
        
        # Store the result in the dictionary
        top_pairs_per_coin[coin] = top_pairs
        
        # Add the selected pairs to the final set
        final_pairs_set.update((coin, pair) for pair in top_pairs.index)

    # Convert the set to a sorted list
    final_pairs = sorted(final_pairs_set)
    
    # Determine the update date as the end date of crypto_px + 1 day
    update_date = crypto_px.index[-1] + pd.Timedelta(days=1)
    print(f"Pairs Updated date: {update_date.strftime('%Y-%m-%d')}")
    
    # Display the top correlated pairs for each coin with their actual correlation values
    sorted_coins = sorted(top_pairs_per_coin.keys())
    
    # Print the final pairs and the count
    print(f"Final pairs to be traded: {final_pairs}")
    print(f"Number of pairs to be traded: {len(final_pairs)}")
    
    return final_pairs

# %% [markdown]
# ### Trading Strategy
#
# #### 1. Signal Generation
#
# - **Residual Calculation:**
#
#   $$
#   \epsilon_t = \log(p_{i,t}) - (\beta_t \log(p_{j,t}) + \alpha_t)
#   $$
#
#   where:
#   - $\log(p_{i,t})$ and $\log(p_{j,t})$ are the log prices of coins $i$ and $j$ at time $t$.
#   - **$\beta_t$** is calculated as:
#
#    $$
#    \beta_t = \text{Corr}_{t} \times \frac{\text{Vol}_{j,t}}{\text{Vol}_{i,t}}
#    $$
#
#
#     with:
#     - **$\text{Corr}_{t}$** is the 90-day rolling correlation between $\log(p_{i,t})$ and $\log(p_{j,t})$.
#     - **$\text{Vol}_{i,t}$** and **$\text{Vol}_{j,t}$** are the 90-day rolling volatilities of $\log(p_{i,t})$ and $\log(p_{j,t})$, respectively.
#   - **$\alpha_t$** is calculated as:
#
#   $$
#   \alpha_t = \mu_{\log(p_{j,t})} - \beta_t \cdot \mu_{\log(p_{i,t})}
#   $$
#
#   where:
#   - $\mu_{\log(p_{j,t},90)}$ is the 90-day rolling mean of $\log(p_{j,t})$.
#   - $\mu_{\log(p_{i,t},90)}$ is the 90-day rolling mean of $\log(p_{i,t})$.
#
#
# - **Z-Score Calculation:**
#
#   $$
#   z_t = \frac{\epsilon_t - \mu_t}{\sigma_t}
#   $$
#
#   where:
#   - $\mu_t$ is the 90-day rolling mean of the spread.
#   - $\sigma_t$ is the 90-day rolling standard deviation of the spread.
#
# #### 2. Portfolio Construction
#
# - **Entry Signals:**
#   - **Short** coin $i$ and **long** $\beta_t$ units of coin $j$ if $z_t > 1$.
#   - **Long** coin $i$ and **short** $\beta_t$ units of coin $j$ if $z_t < -1$.
#
# - **Exit Signals:**
#   - Close the position when $z_t$ moves to any of the following thresholds:
#
#     $$
#     z_t \geq -\text{threshold} \quad \text{or} \quad z_t \leq \text{threshold}
#     $$
#
#     where threshold is one of the values: 0.1, 0.2, 0.5, or 0.7.

# %%
def gen_signals(px, pairs, window=90):
    signal_df = {}
    for pair in pairs:
        asset_i, asset_j = pair
        
        # Forward-fill missing values and replace zeros with NaNs
        px_i = px[asset_i].replace(0, np.nan).ffill()
        px_j = px[asset_j].replace(0, np.nan).ffill()
        
        # Apply log transformation
        log_px_i = np.log(px_i)
        log_px_j = np.log(px_j)
        
        # Calculate rolling covariance and variance 
        rolling_cov = log_px_i.rolling(window=window, min_periods=1).cov(log_px_j)
        rolling_var = log_px_i.rolling(window=window, min_periods=1).var()
        
        # Calculate beta and alpha
        beta = rolling_cov / rolling_var
        alpha = log_px_j.rolling(window=window).mean() - beta * log_px_i.rolling(window=window).mean()
        
        # Calculate spread for time t using beta and alpha
        spread = log_px_i - (beta * log_px_j + alpha)
        
        # Calculate rolling mean and standard deviation of the spread using data up to t
        spread_mean = spread.rolling(window=window, min_periods=1).mean()
        spread_std = spread.rolling(window=window, min_periods=1).std()
        
        # Calculate the z-score for time t using spread(t), mean(t), and std(t)
        z_score = (spread - spread_mean) / spread_std
        
        # Store beta, alpha, spread, and z-score in a multi-level column DataFrame
        signal_df[(pair, 'beta')] = beta
        signal_df[(pair, 'alpha')] = alpha
        signal_df[(pair, 'spread')] = spread
        signal_df[(pair, 'z_score')] = z_score
    
    # Convert the dictionary to a DataFrame
    signal_df = pd.DataFrame(signal_df)
    
    return signal_df

# %%
def gen_port(signal_df, pairs, crypto_px, threshold=0.5):
    # Initialize a DataFrame with the same index and columns as crypto_px, filled with NaN
    pos = pd.DataFrame(index=signal_df.index, columns=crypto_px.columns)
    for pair in pairs:
        asset_i, asset_j = pair
        # Access z-scores and betas for this pair
        z_scores = signal_df[(pair, 'z_score')]
        betas = signal_df[(pair, 'beta')]

        # Set positions based on z-scores
        pos.loc[z_scores > 1, asset_i] = -1  # Short one unit of asset_i
        pos.loc[z_scores < -1, asset_i] = 1  # Long one unit of asset_i
        pos.loc[(z_scores.abs() <= threshold), asset_i] = 0  # Exit signal

        pos.loc[z_scores > 1, asset_j] = betas  # Long beta units of asset_j
        pos.loc[z_scores < -1, asset_j] = -betas  # Short beta units of asset_j
        pos.loc[(z_scores.abs() <= threshold), asset_j] = 0  # Exit signal

    # Forward-fill missing values
    pos = pos.ffill()
    # Normalize to ensure a fully-invested portfolio
    pos = pos.divide(pos.abs().sum(axis=1), axis=0).fillna(0)
    return pos

# %% [markdown]
# ### Performance Evaluation
#
# We evaluate the strategy's performance across four exit thresholds: 0.1, 0.2, 0.5, and 0.7. For each threshold, the following key metrics are calculated:
#
# - **Sharpe Ratio**: Risk-adjusted return of the strategy.
# - **Transaction Costs**: Average costs incurred due to trading.
# - **Holding Period**: Average number of days a position is held.
# - **Turnover**: Average daily proportion of the portfolio that is traded.
# - **Annualized Return**: Average yearly return of the strategy.
# - **Annualized Volatility**: Standard deviation of returns on an annual basis, indicating risk.
#
# Cryptocurrencies can have commissions of ~7bps. While total slippage is unknown and will depend on the trader’s volume as well, let’s assume another 13 bps. So total all-in execution costs will be 20 bps for market-orders.

# %%
# Define the thresholds and initialize the arrays for storing metrics
end_of_insample = pd.Timestamp('2019-12-31')
last_available_date = crypto_px.index[-1]
thresholds = [0.1, 0.2, 0.5, 0.7]
metrics = {
    'Sharpe Ratio': np.zeros(len(thresholds)),
    'Return': np.zeros(len(thresholds)),
    'Volatility': np.zeros(len(thresholds)),
    'Holding Period': np.zeros(len(thresholds)),
    'Turnover': np.zeros(len(thresholds)),
    'Transaction Costs': np.zeros(len(thresholds)),
}
# Dictionary to store strat_net_ret for each threshold
strat_net_ret_dict = {}

# Set the start of the out-of-sample period
start_of_out_sample = end_of_insample + pd.DateOffset(days=1)

# Define half-year periods for updating pairs
update_dates = pd.date_range(start=start_of_out_sample, end=crypto_px.index[-1], freq='3MS')

# Initialize an empty DataFrame to store the complete portfolio over all periods
full_portfolio = pd.DataFrame(index=crypto_px.loc[start_of_out_sample:].index, columns=crypto_px.columns)

# Loop over each threshold to calculate metrics
for i, threshold in enumerate(thresholds):
    for start_date in update_dates:
        # Define the end of the update period (6 months later)
        end_date = start_date + pd.DateOffset(months=3) - pd.DateOffset(days=1)
        
        # Adjust end_date if it exceeds the last available date
        if end_date > last_available_date:
            end_date = last_available_date
            
        # Select the in-sample period for pair selection
        insample_start = start_date - pd.DateOffset(years=2)
        insample_end = start_date - pd.DateOffset(days=1)
        
        # Re-select pairs based on the ADF test or any other criteria
        updated_pairs = select_pairs(crypto_px.loc[insample_start:insample_end])
        
        # Generate signals for the new pairs
        signal_df = gen_signals(crypto_px, updated_pairs, window=90)
        signal_df = signal_df.loc[start_date:end_date]
        
        # Generate portfolio for the selected pairs
        port = gen_port(signal_df, updated_pairs, crypto_px, threshold)
        
        # Store the generated portfolio in the full_portfolio DataFrame
        full_portfolio.loc[start_date:end_date, :] = port
    
    # Calculate out-of-sample daily returns for the entire period
    out_sample_ret = coins_ret.loc[start_of_out_sample:][full_portfolio.columns]
    strat_gross_ret = (full_portfolio.shift() * out_sample_ret).sum(axis=1)
    
    # Calculate net returns with transaction costs
    to = compute_turnover(full_portfolio)
    tcost_bps = 20  # (commissions + slippage)
    strat_net_ret = strat_gross_ret.subtract(to * tcost_bps * 1e-4, fill_value=0)
    
    # Store the net returns for the current threshold
    strat_net_ret_dict[threshold] = strat_net_ret
    
    # Compute Sharpe ratio
    sharpe_ratio = compute_sharpe_ratio(strat_net_ret)
    metrics['Sharpe Ratio'][i] = sharpe_ratio
    
    # Compute transaction costs
    total_tcost = to * tcost_bps * 1e-4
    metrics['Transaction Costs'][i] = total_tcost.sum()
    
    # Compute holding period (average number of days a position is held)
    metrics['Holding Period'][i] = 2/to.mean()
    
    # Store turnover
    metrics['Turnover'][i] = to.mean()
    
    # Compute return 
    returns = strat_net_ret.mean()
    metrics['Return'][i] = returns
    
    # Compute volatility
    volatility = strat_net_ret.std()
    metrics['Volatility'][i] = volatility
    
# Convert metrics to a DataFrame for easier visualization
metrics_df = pd.DataFrame(metrics, index=thresholds)
# Out:
# Pairs Updated date: 2020-01-01
# Final pairs to be traded: [('ADA', 'CVC'), ('ADA', 'GNO'), ('ADA', 'POWR'), ('ADA', 'SNT'), ('ADA', 'XEM'), ('ADX', 'DASH'), ('ADX', 'POWR'), ('ADX', 'REQ'), ('ADX', 'STRAX'), ('ADX', 'VIB'), ('AMB', 'BLZ'), ('AMB', 'ELF'), ('AMB', 'LRC'), ('AMB', 'PRO'), ('AMB', 'STEEM'), ('ANT', 'BLZ'), ('ANT', 'CTXC'), ('ANT', 'STEEM'), ('ANT', 'SWFTC'), ('ANT', 'SYS'), ('ARDR', 'ADA'), ('ARDR', 'BTG'), ('ARDR', 'CTXC'), ('ARDR', 'SWFTC'), ('ARDR', 'XEM'), ('ARK', 'ADX'), ('ARK', 'DASH'), ('ARK', 'ICX'), ('ARK', 'PIVX'), ('ARK', 'STRAX'), ('BCH', 'BLZ'), ('BCH', 'DASH'), ('BCH', 'IOTA'), ('BCH', 'STORJ'), ('BCH', 'ZEC'), ('BLZ', 'CVC'), ('BLZ', 'ELF'), ('BLZ', 'IOTA'), ('BLZ', 'LRC'), ('BLZ', 'STEEM'), ('BORG', 'DENT'), ('BORG', 'LSK'), ('BORG', 'MLN'), ('BORG', 'NEO'), ('BORG', 'QTUM'), ('BTG', 'ADX'), ('BTG', 'ARDR'), ('BTG', 'GNO'), ('BTG', 'REQ'), ('BTG', 'XEM'), ('CTXC', 'ELF'), ('CTXC', 'GAS'), ('CTXC', 'ICX'), ('CTXC', 'LRC'), ('CTXC', 'SYS'), ('CVC', 'ADA'), ('CVC', 'BLZ'), ('CVC', 'POWR'), ('CVC', 'SNT'), ('CVC', 'XEM'), ('DASH', 'ADX'), ('DASH', 'ARK'), ('DASH', 'POWR'), ('DASH', 'STORJ'), ('DASH', 'ZEC'), ('DCR', 'BCH'), ('DCR', 'GLM'), ('DCR', 'NULS'), ('DCR', 'ONT'), ('DCR', 'ZEN'), ('DENT', 'CTXC'), ('DENT', 'GNO'), ('DENT', 'REQ'), ('DENT', 'UTK'), ('DENT', 'XEM'), ('DGB', 'BCH'), ('DGB', 'CVC'), ('DGB', 'FUN'), ('DGB', 'POWR'), ('DGB', 'XLM'), ('ELF', 'AMB'), ('ELF', 'BLZ'), ('ELF', 'CTXC'), ('ELF', 'IOTA'), ('ELF', 'STEEM'), ('EOS', 'CTXC'), ('EOS', 'IOST'), ('EOS', 'ONT'), ('EOS', 'ZIL'), ('ETC', 'DASH'), ('ETC', 'OMG'), ('ETC', 'XMR'), ('ETC', 'ZEC'), ('ETC', 'ZEN'), ('FUN', 'BLZ'), ('FUN', 'CVC'), ('FUN', 'GNO'), ('FUN', 'POWR'), ('FUN', 'STRAX'), ('GAS', 'CTXC'), ('GAS', 'LSK'), ('GAS', 'MDT'), ('GAS', 'NEO'), ('GAS', 'SWFTC'), ('GFT', 'BLZ'), ('GFT', 'CTXC'), ('GFT', 'OMG'), ('GFT', 'SWFTC'), ('GFT', 'SYS'), ('GLM', 'BCH'), ('GLM', 'CTXC'), ('GLM', 'ELF'), ('GLM', 'IOTA'), ('GLM', 'ONT'), ('GNO', 'ADX'), ('GNO', 'POWR'), ('GNO', 'REQ'), ('GNO', 'VIB'), ('GNO', 'XEM'), ('ICX', 'ARK'), ('ICX', 'BLZ'), ('ICX', 'CTXC'), ('ICX', 'PIVX'), ('ICX', 'STRAX'), ('IDEX', 'BCH'), ('IDEX', 'CVC'), ('IDEX', 'IOTA'), ('IDEX', 'STEEM'), ('IDEX', 'ZEC'), ('IOST', 'BLZ'), ('IOST', 'CTXC'), ('IOST', 'CVC'), ('IOST', 'ELF'), ('IOST', 'LRC'), ('IOTA', 'BCH'), ('IOTA', 'BLZ'), ('IOTA', 'CTXC'), ('IOTA', 'GLM'), ('IOTA', 'STORJ'), ('LRC', 'AMB'), ('LRC', 'BLZ'), ('LRC', 'CTXC'), ('LRC', 'ELF'), ('LRC', 'ICX'), ('LSK', 'CTXC'), ('LSK', 'GAS'), ('LSK', 'NEO'), ('LSK', 'SYS'), ('LSK', 'ZEC'), ('LTC', 'XMR'), ('MANA', 'ELF'), ('MANA', 'GLM'), ('MANA', 'NULS'), ('MANA', 'XLM'), ('MANA', 'ZEN'), ('MDT', 'ADX'), ('MDT', 'GAS'), ('MDT', 'QTUM'), ('MDT', 'REQ'), ('MDT', 'VIB'), ('MED', 'ARDR'), ('MED', 'MDT'), ('MED', 'SWFTC'), ('MED', 'UTK'), ('MED', 'WAXP'), ('MLN', 'ADX'), ('MLN', 'ARK'), ('MLN', 'GNO'), ('MLN', 'STRAX'), ('MLN', 'VIB'), ('MTL', 'CTXC'), ('MTL', 'IOTA'), ('MTL', 'MDT'), ('MTL', 'OMG'), ('MTL', 'SYS'), ('NEO', 'CTXC'), ('NEO', 'GAS'), ('NEO', 'LSK'), ('NEO', 'MDT'), ('NEO', 'SYS'), ('NMR', 'ADX'), ('NMR', 'BTG'), ('NMR', 'GNO'), ('NMR', 'REQ'), ('NMR', 'VIB'), ('NULS', 'BCH'), ('NULS', 'CTXC'), ('NULS', 'DCR'), ('NULS', 'ELF'), ('NULS', 'TRAC'), ('OMG', 'ANT'), ('OMG', 'BLZ'), ('OMG', 'CTXC'), ('OMG', 'SWFTC'), ('OMG', 'SYS'), ('ONT', 'CTXC'), ('ONT', 'DCR'), ('ONT', 'GLM'), ('ONT', 'NULS'), ('ONT', 'ZIL'), ('PIVX', 'ARK'), ('PIVX', 'DASH'), ('PIVX', 'ICX'), ('PIVX', 'STORJ'), ('PIVX', 'STRAX'), ('POWR', 'ADA'), ('POWR', 'ADX'), ('POWR', 'CVC'), ('POWR', 'GNO'), ('POWR', 'SNT'), ('PRO', 'CVC'), ('PRO', 'FUN'), ('PRO', 'GNO'), ('PRO', 'STMX'), ('PRO', 'VIB'), ('QTUM', 'ADX'), ('QTUM', 'CTXC'), ('QTUM', 'DASH'), ('QTUM', 'MDT'), ('QTUM', 'REQ'), ('REQ', 'ADX'), ('REQ', 'CVC'), ('REQ', 'GNO'), ('REQ', 'POWR'), ('REQ', 'XEM'), ('RLC', 'ANT'), ('RLC', 'ICX'), ('RLC', 'IOTA'), ('RLC', 'PIVX'), ('RLC', 'TRAC'), ('SBD', 'ADA'), ('SBD', 'ADX'), ('SBD', 'BTG'), ('SBD', 'POWR'), ('SBD', 'QTUM'), ('SNT', 'ADA'), ('SNT', 'CVC'), ('SNT', 'GNO'),  ...
# Number of pairs to be traded: 364
# Pairs Updated date: 2020-04-01
# Final pairs to be traded: [('ADA', 'ARDR'), ('ADA', 'GNO'), ('ADA', 'IOST'), ('ADA', 'SNT'), ('ADA', 'XEM'), ('ADX', 'LRC'), ('ADX', 'REQ'), ('ADX', 'SNT'), ('ADX', 'STMX'), ('ADX', 'SYS'), ('AMB', 'BLZ'), ('AMB', 'ELF'), ('AMB', 'GAS'), ('AMB', 'GFT'), ('AMB', 'STRAX'), ('ANT', 'GNO'), ('ANT', 'ICX'), ('ANT', 'LRC'), ('ANT', 'NEO'), ('ANT', 'SWFTC'), ('ARDR', 'NEO'), ('ARDR', 'QTUM'), ('ARDR', 'SNT'), ('ARDR', 'STORJ'), ('ARDR', 'XEM'), ('ARK', 'GAS'), ('ARK', 'PIVX'), ('ARK', 'STORJ'), ('ARK', 'STRAX'), ('ARK', 'SYS'), ('BCH', 'ADA'), ('BCH', 'DASH'), ('BCH', 'EOS'), ('BCH', 'IOST'), ('BCH', 'IOTA'), ('BLZ', 'ELF'), ('BLZ', 'GAS'), ('BLZ', 'IOTA'), ('BLZ', 'OMG'), ('BLZ', 'SNT'), ('BTG', 'ARDR'), ('BTG', 'DASH'), ('BTG', 'WAXP'), ('BTG', 'XEM'), ('BTG', 'XMR'), ('CTXC', 'ELF'), ('CTXC', 'GAS'), ('CTXC', 'ICX'), ('CTXC', 'LRC'), ('CTXC', 'SYS'), ('CVC', 'ARK'), ('CVC', 'BLZ'), ('CVC', 'OMG'), ('CVC', 'SNT'), ('CVC', 'STRAX'), ('DASH', 'ADA'), ('DASH', 'ARDR'), ('DASH', 'SNT'), ('DASH', 'XEM'), ('DASH', 'XMR'), ('DCR', 'IDEX'), ('DCR', 'NULS'), ('DCR', 'ONT'), ('DCR', 'ZEC'), ('DCR', 'ZIL'), ('DENT', 'LSK'), ('DENT', 'MTL'), ('DENT', 'PIVX'), ('DENT', 'QTUM'), ('DENT', 'REQ'), ('DGB', 'IDEX'), ('DGB', 'MANA'), ('DGB', 'XLM'), ('DGB', 'ZEC'), ('DGB', 'ZRX'), ('ELF', 'BLZ'), ('ELF', 'CTXC'), ('ELF', 'GAS'), ('ELF', 'IOTA'), ('ELF', 'STRAX'), ('EOS', 'ADA'), ('EOS', 'BCH'), ('EOS', 'CTXC'), ('EOS', 'IOST'), ('EOS', 'TRX'), ('ETC', 'BCH'), ('ETC', 'DASH'), ('ETC', 'FUN'), ('ETC', 'ZEC'), ('ETC', 'ZEN'), ('FUN', 'BLZ'), ('FUN', 'CVC'), ('FUN', 'LSK'), ('FUN', 'OMG'), ('FUN', 'SNT'), ('GAS', 'ICX'), ('GAS', 'LRC'), ('GAS', 'OMG'), ('GAS', 'SNT'), ('GAS', 'STRAX'), ('GFT', 'ELF'), ('GFT', 'GAS'), ('GFT', 'ICX'), ('GFT', 'LRC'), ('GFT', 'STMX'), ('GLM', 'BLZ'), ('GLM', 'CTXC'), ('GLM', 'ELF'), ('GLM', 'GAS'), ('GLM', 'IOTA'), ('GNO', 'NEO'), ('GNO', 'OMG'), ('GNO', 'QTUM'), ('GNO', 'SNT'), ('GNO', 'XEM'), ('ICX', 'ARK'), ('ICX', 'GAS'), ('ICX', 'LRC'), ('ICX', 'STMX'), ('ICX', 'SYS'), ('IDEX', 'DCR'), ('IDEX', 'GLM'), ('IDEX', 'IOTA'), ('IDEX', 'NULS'), ('IDEX', 'ZIL'), ('IOST', 'ADA'), ('IOST', 'CTXC'), ('IOST', 'ELF'), ('IOST', 'GAS'), ('IOST', 'SWFTC'), ('IOTA', 'BLZ'), ('IOTA', 'GAS'), ('IOTA', 'GLM'), ('IOTA', 'ICX'), ('IOTA', 'OMG'), ('LRC', 'GAS'), ('LRC', 'ICX'), ('LRC', 'OMG'), ('LRC', 'STMX'), ('LRC', 'SYS'), ('LSK', 'GAS'), ('LSK', 'OMG'), ('LSK', 'SNT'), ('LSK', 'SYS'), ('LSK', 'XEM'), ('MANA', 'DGB'), ('MANA', 'POWR'), ('MANA', 'XLM'), ('MANA', 'ZEC'), ('MANA', 'ZRX'), ('MDT', 'ANT'), ('MDT', 'LRC'), ('MDT', 'MTL'), ('MDT', 'STMX'), ('MDT', 'SWFTC'), ('MED', 'MDT'), ('MED', 'MLN'), ('MED', 'REQ'), ('MED', 'STMX'), ('MED', 'SYS'), ('MLN', 'ARK'), ('MLN', 'LRC'), ('MLN', 'MTL'), ('MLN', 'PIVX'), ('MLN', 'REQ'), ('MTL', 'LRC'), ('MTL', 'MLN'), ('MTL', 'NEO'), ('MTL', 'QTUM'), ('MTL', 'REQ'), ('NEO', 'GAS'), ('NEO', 'GNO'), ('NEO', 'OMG'), ('NEO', 'QTUM'), ('NEO', 'XEM'), ('NULS', 'DCR'), ('NULS', 'GLM'), ('NULS', 'IDEX'), ('NULS', 'ZEC'), ('NULS', 'ZIL'), ('OMG', 'GAS'), ('OMG', 'LSK'), ('OMG', 'QTUM'), ('OMG', 'SNT'), ('OMG', 'XEM'), ('ONT', 'CTXC'), ('ONT', 'DCR'), ('ONT', 'GLM'), ('ONT', 'NULS'), ('ONT', 'ZIL'), ('PIVX', 'ARK'), ('PIVX', 'GAS'), ('PIVX', 'REQ'), ('PIVX', 'STRAX'), ('PIVX', 'SYS'), ('POWR', 'BLZ'), ('POWR', 'CVC'), ('POWR', 'FUN'), ('POWR', 'SNT'), ('POWR', 'STEEM'), ('PRO', 'ADX'), ('PRO', 'ARDR'), ('PRO', 'OMG'), ('PRO', 'SNT'), ('PRO', 'XEM'), ('QTUM', 'MTL'), ('QTUM', 'NEO'), ('QTUM', 'OMG'), ('QTUM', 'SNT'), ('QTUM', 'XEM'), ('REQ', 'ADX'), ('REQ', 'LRC'), ('REQ', 'PIVX'), ('REQ', 'STMX'), ('REQ', 'SYS'), ('SBD', 'ADX'), ('SBD', 'ARDR'), ('SBD', 'REQ'), ('SBD', 'WAXP'), ('SBD', 'XNO'), ('SNT', 'ARDR'), ('SNT', 'BLZ'), ('SNT', 'GAS'), ('SNT', 'OMG'), ('SNT', 'XEM'), ('STEEM', 'BLZ'), ('STEEM', 'GAS'), ('STEEM', 'OMG'), ('STEEM', 'POWR'), ('STEEM', 'SNT'), ('STMX', 'ADX'), ('STMX', 'ICX'), ('STMX', 'LRC'), ('STMX', 'REQ'), ('STMX', 'SYS'), ('STORJ', 'ADX'), ('STORJ', 'ARDR'), ('STORJ', 'ARK'), ('STORJ', ...
# Number of pairs to be traded: 346
# Pairs Updated date: 2020-07-01
# Final pairs to be traded: [('ADA', 'GNO'), ('ADA', 'IOST'), ('ADA', 'OMG'), ('ADA', 'POWR'), ('ADA', 'SNT'), ('ADX', 'BLZ'), ('ADX', 'ELF'), ('ADX', 'GFT'), ('ADX', 'GLM'), ('ADX', 'XVG'), ('AMB', 'BLZ'), ('AMB', 'GFT'), ('AMB', 'GLM'), ('AMB', 'REQ'), ('AMB', 'STMX'), ('ARDR', 'CVC'), ('ARDR', 'DCR'), ('ARDR', 'NULS'), ('ARDR', 'QTUM'), ('ARDR', 'ZEC'), ('ARK', 'ADX'), ('ARK', 'CVC'), ('ARK', 'PIVX'), ('ARK', 'STRAX'), ('ARK', 'SYS'), ('BCH', 'DASH'), ('BCH', 'ETC'), ('BCH', 'NEO'), ('BCH', 'XMR'), ('BCH', 'ZEN'), ('BLZ', 'ELF'), ('BLZ', 'GAS'), ('BLZ', 'GFT'), ('BLZ', 'GLM'), ('BLZ', 'STMX'), ('CTXC', 'ELF'), ('CTXC', 'GAS'), ('CTXC', 'GLM'), ('CTXC', 'OMG'), ('CTXC', 'ONT'), ('CVC', 'ARK'), ('CVC', 'ELF'), ('CVC', 'REQ'), ('CVC', 'SYS'), ('CVC', 'XVG'), ('DASH', 'ARDR'), ('DASH', 'EOS'), ('DASH', 'XEM'), ('DASH', 'XMR'), ('DASH', 'ZEC'), ('DCR', 'ELF'), ('DCR', 'GLM'), ('DCR', 'NULS'), ('DCR', 'OMG'), ('DCR', 'QTUM'), ('DENT', 'CTXC'), ('DENT', 'CVC'), ('DENT', 'GAS'), ('DENT', 'STRAX'), ('DENT', 'XVG'), ('DGB', 'OMG'), ('DGB', 'POWR'), ('DGB', 'SNT'), ('DGB', 'ZIL'), ('DGB', 'ZRX'), ('ELF', 'BLZ'), ('ELF', 'GAS'), ('ELF', 'GFT'), ('ELF', 'GLM'), ('ELF', 'OMG'), ('EOS', 'DASH'), ('EOS', 'IOST'), ('ETC', 'BCH'), ('ETC', 'NEO'), ('ETC', 'ZEN'), ('FUN', 'ELF'), ('FUN', 'GAS'), ('FUN', 'GFT'), ('FUN', 'OMG'), ('FUN', 'STMX'), ('GAS', 'BLZ'), ('GAS', 'ELF'), ('GAS', 'GFT'), ('GAS', 'GLM'), ('GAS', 'OMG'), ('GFT', 'BLZ'), ('GFT', 'ELF'), ('GFT', 'GAS'), ('GFT', 'GLM'), ('GFT', 'STMX'), ('GLM', 'BLZ'), ('GLM', 'ELF'), ('GLM', 'GAS'), ('GLM', 'OMG'), ('GLM', 'STMX'), ('GNO', 'ADA'), ('GNO', 'NEO'), ('GNO', 'SNT'), ('ICX', 'BLZ'), ('ICX', 'GAS'), ('ICX', 'GLM'), ('ICX', 'LRC'), ('ICX', 'OMG'), ('IDEX', 'ELF'), ('IDEX', 'GAS'), ('IDEX', 'NULS'), ('IDEX', 'OMG'), ('IDEX', 'XVG'), ('IOST', 'ARDR'), ('IOST', 'NULS'), ('IOST', 'ONT'), ('IOST', 'QTUM'), ('IOST', 'STORJ'), ('IOTA', 'BLZ'), ('IOTA', 'ELF'), ('IOTA', 'GAS'), ('IOTA', 'GLM'), ('IOTA', 'OMG'), ('LRC', 'BLZ'), ('LRC', 'GLM'), ('LRC', 'ICX'), ('LRC', 'STMX'), ('LRC', 'ZIL'), ('LSK', 'ELF'), ('LSK', 'FUN'), ('LSK', 'GAS'), ('LSK', 'NULS'), ('LSK', 'OMG'), ('MANA', 'ADX'), ('MANA', 'SYS'), ('MANA', 'XEM'), ('MANA', 'XVG'), ('MANA', 'ZEC'), ('MTL', 'BLZ'), ('MTL', 'GAS'), ('MTL', 'GLM'), ('MTL', 'NEO'), ('MTL', 'OMG'), ('NEO', 'GAS'), ('NEO', 'ICX'), ('NEO', 'IOTA'), ('NEO', 'OMG'), ('NEO', 'QTUM'), ('NULS', 'ELF'), ('NULS', 'GAS'), ('NULS', 'GFT'), ('NULS', 'OMG'), ('NULS', 'XVG'), ('OMG', 'BLZ'), ('OMG', 'ELF'), ('OMG', 'GAS'), ('OMG', 'GLM'), ('OMG', 'STMX'), ('ONT', 'CTXC'), ('ONT', 'ELF'), ('ONT', 'GAS'), ('ONT', 'GLM'), ('ONT', 'OMG'), ('PIVX', 'ARK'), ('PIVX', 'CVC'), ('PIVX', 'REQ'), ('PIVX', 'STRAX'), ('PIVX', 'ZIL'), ('POWR', 'ADX'), ('POWR', 'ELF'), ('POWR', 'GFT'), ('POWR', 'SNT'), ('POWR', 'ZIL'), ('PRO', 'CVC'), ('PRO', 'ELF'), ('PRO', 'GLM'), ('PRO', 'OMG'), ('PRO', 'XVG'), ('QTUM', 'DCR'), ('QTUM', 'IOTA'), ('QTUM', 'NEO'), ('QTUM', 'OMG'), ('QTUM', 'XEM'), ('REQ', 'AMB'), ('REQ', 'CVC'), ('REQ', 'PIVX'), ('REQ', 'STMX'), ('REQ', 'XVG'), ('SNT', 'GLM'), ('SNT', 'ICX'), ('SNT', 'OMG'), ('SNT', 'POWR'), ('SNT', 'ZIL'), ('STEEM', 'BLZ'), ('STEEM', 'GAS'), ('STEEM', 'GFT'), ('STEEM', 'GLM'), ('STEEM', 'STMX'), ('STMX', 'BLZ'), ('STMX', 'GAS'), ('STMX', 'GFT'), ('STMX', 'GLM'), ('STMX', 'OMG'), ('STORJ', 'ADX'), ('STORJ', 'ARDR'), ('STORJ', 'ARK'), ('STORJ', 'CVC'), ('STORJ', 'IOST'), ('STRAX', 'ARK'), ('STRAX', 'PIVX'), ('STRAX', 'SYS'), ('STRAX', 'XVG'), ('STRAX', 'ZIL'), ('SWFTC', 'ICX'), ('SWFTC', 'IOST'), ('SWFTC', 'MTL'), ('SWFTC', 'ONT'), ('SWFTC', 'QTUM'), ('SYS', 'ADX'), ('SYS', 'ELF'), ('SYS', 'GAS'), ('SYS', 'GLM'), ('SYS', 'XVG'), ('TRAC', 'LRC'), ('VGX', 'LRC'), ('VIB', 'ADX'), ('VIB', 'ARDR'), ('VIB', 'CVC'), ('VIB', 'IOST'), ('VIB', 'STORJ'), ('XEM', 'GLM'), ('XEM', 'IOTA'), ('XEM', 'OMG'), ('XEM', 'QTUM'), ('XEM', 'ZEC'), ('XLM', 'CVC'), ('XLM', 'MANA'), ('XLM', 'REQ'), ('XLM', 'ZEC'), ('XLM', 'ZRX'), ('XMR', 'BCH'), ('XMR', 'DASH'), ('XMR', 'DCR'), ('XNO ...
# Number of pairs to be traded: 264
# Pairs Updated date: 2020-10-01
# Final pairs to be traded: [('ADX', 'BLZ'), ('ADX', 'SYS'), ('AMB', 'FUN'), ('AMB', 'GFT'), ('AMB', 'STEEM'), ('AMB', 'STMX'), ('AMB', 'XLM'), ('ANT', 'LINK'), ('ANT', 'MLN'), ('ANT', 'REN'), ('ANT', 'SNX'), ('ANT', 'TRAC'), ('ARDR', 'CTXC'), ('ARDR', 'IOTA'), ('ARDR', 'NULS'), ('ARDR', 'ONT'), ('ARDR', 'QTUM'), ('ARK', 'PIVX'), ('ARK', 'STRAX'), ('BLZ', 'ADX'), ('BLZ', 'SYS'), ('BTG', 'DASH'), ('CTXC', 'ARDR'), ('CTXC', 'ELF'), ('CTXC', 'GAS'), ('CTXC', 'NULS'), ('CTXC', 'ONT'), ('CVC', 'ELF'), ('CVC', 'GAS'), ('CVC', 'GFT'), ('CVC', 'NULS'), ('CVC', 'STEEM'), ('DASH', 'BTG'), ('DASH', 'EOS'), ('DENT', 'CVC'), ('DENT', 'GAS'), ('DENT', 'GFT'), ('DENT', 'XRP'), ('ELF', 'CTXC'), ('ELF', 'CVC'), ('ELF', 'GAS'), ('ELF', 'STEEM'), ('ELF', 'XVG'), ('EOS', 'DASH'), ('FUN', 'GAS'), ('FUN', 'STEEM'), ('FUN', 'STMX'), ('FUN', 'XLM'), ('FUN', 'XVG'), ('GAS', 'CVC'), ('GAS', 'ELF'), ('GAS', 'GFT'), ('GAS', 'STEEM'), ('GAS', 'XVG'), ('GFT', 'AMB'), ('GFT', 'CVC'), ('GFT', 'ELF'), ('GFT', 'GAS'), ('GFT', 'STEEM'), ('GLM', 'LSK'), ('GNO', 'THETA'), ('GNO', 'TRAC'), ('IDEX', 'OMG'), ('IOST', 'ONT'), ('IOTA', 'ARDR'), ('IOTA', 'XRP'), ('LINK', 'ANT'), ('LINK', 'REN'), ('LINK', 'SNX'), ('LRC', 'TRAC'), ('LSK', 'CTXC'), ('LSK', 'ELF'), ('LSK', 'GAS'), ('LSK', 'POWR'), ('LSK', 'XVG'), ('MLN', 'ANT'), ('MLN', 'TRAC'), ('NULS', 'ARDR'), ('NULS', 'CTXC'), ('NULS', 'ELF'), ('NULS', 'GAS'), ('NULS', 'ONT'), ('OMG', 'IDEX'), ('ONT', 'ARDR'), ('ONT', 'CTXC'), ('ONT', 'ELF'), ('ONT', 'GAS'), ('ONT', 'NULS'), ('PIVX', 'ARK'), ('PIVX', 'GAS'), ('PIVX', 'GFT'), ('PIVX', 'STEEM'), ('PIVX', 'STRAX'), ('POWR', 'ELF'), ('POWR', 'LSK'), ('POWR', 'ZIL'), ('PRO', 'CVC'), ('PRO', 'GAS'), ('QTUM', 'ARDR'), ('REN', 'ANT'), ('REN', 'LINK'), ('REN', 'SNX'), ('SNX', 'ANT'), ('SNX', 'LINK'), ('SNX', 'REN'), ('SNX', 'XDC'), ('STEEM', 'CVC'), ('STEEM', 'ELF'), ('STEEM', 'GAS'), ('STEEM', 'GFT'), ('STEEM', 'STMX'), ('STMX', 'AMB'), ('STMX', 'FUN'), ('STMX', 'GAS'), ('STMX', 'STEEM'), ('STMX', 'XLM'), ('STRAX', 'ARK'), ('STRAX', 'GAS'), ('STRAX', 'GFT'), ('STRAX', 'PIVX'), ('STRAX', 'XVG'), ('SYS', 'ADX'), ('SYS', 'BLZ'), ('THETA', 'GNO'), ('THETA', 'UQC'), ('TRAC', 'ANT'), ('TRAC', 'GNO'), ('TRAC', 'LRC'), ('TRAC', 'MLN'), ('TRAC', 'UTK'), ('UQC', 'THETA'), ('UTK', 'TRAC'), ('VGX', 'STMX'), ('XDC', 'SNX'), ('XLM', 'AMB'), ('XLM', 'FUN'), ('XLM', 'GAS'), ('XLM', 'STEEM'), ('XLM', 'STMX'), ('XNO', 'ELF'), ('XNO', 'NULS'), ('XNO', 'ONT'), ('XNO', 'XVG'), ('XRP', 'CVC'), ('XRP', 'DENT'), ('XRP', 'IOTA'), ('XVG', 'ELF'), ('XVG', 'GAS'), ('XVG', 'NULS'), ('XVG', 'STMX'), ('XVG', 'XNO'), ('ZIL', 'POWR'), ('ZIL', 'XVG')]
# Number of pairs to be traded: 153
# Pairs Updated date: 2021-01-01
# Final pairs to be traded: [('ANT', 'LINK'), ('ANT', 'MLN'), ('ANT', 'REN'), ('ANT', 'TRAC'), ('ANT', 'UTK'), ('ARDR', 'QTUM'), ('ARK', 'STMX'), ('ARK', 'STRAX'), ('DASH', 'EOS'), ('ELF', 'GAS'), ('EOS', 'DASH'), ('EOS', 'ONT'), ('GAS', 'ELF'), ('GAS', 'STEEM'), ('GFT', 'STEEM'), ('GNO', 'LINK'), ('GNO', 'LRC'), ('GNO', 'THETA'), ('GNO', 'TRAC'), ('IOST', 'NULS'), ('IOST', 'ONT'), ('LINK', 'ANT'), ('LINK', 'REN'), ('LINK', 'SNX'), ('LINK', 'TRAC'), ('LINK', 'XDC'), ('LRC', 'GNO'), ('LRC', 'TRAC'), ('LRC', 'UTK'), ('MLN', 'ANT'), ('MLN', 'TRAC'), ('MLN', 'UTK'), ('NULS', 'IOST'), ('NULS', 'ONT'), ('OMG', 'UTK'), ('ONT', 'EOS'), ('ONT', 'IOST'), ('ONT', 'NULS'), ('PIVX', 'STEEM'), ('PIVX', 'STRAX'), ('QTUM', 'ARDR'), ('REN', 'ANT'), ('REN', 'LINK'), ('REN', 'SNX'), ('REN', 'UTK'), ('REN', 'XDC'), ('SNX', 'LINK'), ('SNX', 'REN'), ('SNX', 'TRAC'), ('SNX', 'XDC'), ('STEEM', 'GAS'), ('STEEM', 'GFT'), ('STEEM', 'PIVX'), ('STMX', 'ARK'), ('STRAX', 'ARK'), ('STRAX', 'PIVX'), ('THETA', 'GNO'), ('TRAC', 'GNO'), ('TRAC', 'LRC'), ('TRAC', 'MLN'), ('TRAC', 'SNX'), ('TRAC', 'UTK'), ('UTK', 'ANT'), ('UTK', 'LRC'), ('UTK', 'OMG'), ('UTK', 'REN'), ('UTK', 'TRAC'), ('XDC', 'LINK'), ('XDC', 'REN'), ('XDC', 'SNX')]
# Number of pairs to be traded: 70
# Pairs Updated date: 2021-04-01
# Final pairs to be traded: [('ADA', 'BNB'), ('ADA', 'BORG'), ('ADA', 'DCR'), ('ADA', 'ICX'), ('ADA', 'VGX'), ('ADX', 'GLM'), ('ADX', 'MDT'), ('ADX', 'SBD'), ('ADX', 'UTK'), ('ADX', 'ZIL'), ('ANT', 'MLN'), ('ARDR', 'ARK'), ('ARDR', 'BAT'), ('ARDR', 'GLM'), ('ARDR', 'IOTA'), ('ARDR', 'POWR'), ('ARK', 'ARDR'), ('ARK', 'GAS'), ('ARK', 'GLM'), ('ARK', 'LSK'), ('ARK', 'POWR'), ('BAT', 'ARDR'), ('BAT', 'ARK'), ('BAT', 'POWR'), ('BAT', 'REQ'), ('BAT', 'SYS'), ('BCH', 'DASH'), ('BCH', 'LTC'), ('BLZ', 'GLM'), ('BLZ', 'REQ'), ('BLZ', 'SYS'), ('BLZ', 'TRAC'), ('BLZ', 'UTK'), ('BNB', 'ADA'), ('BNB', 'DCR'), ('BNB', 'GLM'), ('BNB', 'IOTA'), ('BNB', 'VGX'), ('BORG', 'ADA'), ('BORG', 'ADX'), ('BORG', 'DCR'), ('BORG', 'DOGE'), ('BORG', 'ZIL'), ('BTC', 'BORG'), ('BTC', 'GNO'), ('BTC', 'SBD'), ('BTC', 'SNX'), ('BTC', 'ZIL'), ('CVC', 'ADA'), ('CVC', 'DCR'), ('CVC', 'ICX'), ('CVC', 'IOTA'), ('CVC', 'ZIL'), ('DASH', 'BCH'), ('DASH', 'ZEC'), ('DCR', 'ADA'), ('DCR', 'BNB'), ('DCR', 'CVC'), ('DCR', 'IOST'), ('DCR', 'IOTA'), ('DENT', 'STMX'), ('DGB', 'ICX'), ('DGB', 'REN'), ('DGB', 'SNT'), ('DGB', 'UTK'), ('DGB', 'ZRX'), ('DOGE', 'ADA'), ('DOGE', 'BORG'), ('DOGE', 'FUN'), ('DOGE', 'MKR'), ('DOGE', 'ZRX'), ('ELF', 'ARK'), ('ELF', 'LSK'), ('ELF', 'PIVX'), ('ELF', 'STEEM'), ('ELF', 'STRAX'), ('ENJ', 'BAT'), ('ENJ', 'MANA'), ('ENJ', 'MED'), ('ENJ', 'POWR'), ('ENJ', 'THETA'), ('EOS', 'ONT'), ('FUN', 'DOGE'), ('FUN', 'MKR'), ('FUN', 'XLM'), ('FUN', 'XNO'), ('FUN', 'ZEN'), ('GAS', 'ARK'), ('GAS', 'BNB'), ('GAS', 'GLM'), ('GAS', 'IOST'), ('GAS', 'RVN'), ('GLM', 'ADX'), ('GLM', 'BNB'), ('GLM', 'ICX'), ('GLM', 'IOTA'), ('GLM', 'POWR'), ('GNO', 'BTC'), ('GNO', 'LINK'), ('GNO', 'LRC'), ('GNO', 'REN'), ('GNO', 'SNX'), ('ICX', 'ADA'), ('ICX', 'CVC'), ('ICX', 'GLM'), ('ICX', 'IOTA'), ('ICX', 'SNT'), ('IOST', 'BNB'), ('IOST', 'CVC'), ('IOST', 'DCR'), ('IOST', 'IOTA'), ('IOST', 'VGX'), ('IOTA', 'BNB'), ('IOTA', 'CVC'), ('IOTA', 'DCR'), ('IOTA', 'ICX'), ('IOTA', 'IOST'), ('LINK', 'GNO'), ('LINK', 'LRC'), ('LINK', 'REN'), ('LINK', 'SNX'), ('LINK', 'UTK'), ('LRC', 'GNO'), ('LRC', 'LINK'), ('LRC', 'REN'), ('LRC', 'SNX'), ('LRC', 'XLM'), ('LSK', 'ARDR'), ('LSK', 'ARK'), ('LSK', 'ELF'), ('LSK', 'POWR'), ('LSK', 'STRAX'), ('LTC', 'BCH'), ('LTC', 'XLM'), ('MANA', 'ENJ'), ('MANA', 'MDT'), ('MANA', 'MED'), ('MANA', 'REQ'), ('MANA', 'THETA'), ('MDT', 'ADX'), ('MDT', 'REQ'), ('MDT', 'TRAC'), ('MDT', 'UTK'), ('MDT', 'ZIL'), ('MED', 'ENJ'), ('MED', 'MANA'), ('MED', 'STMX'), ('MED', 'THETA'), ('MKR', 'DOGE'), ('MKR', 'FUN'), ('MKR', 'XLM'), ('MKR', 'XNO'), ('MKR', 'ZEN'), ('MLN', 'ANT'), ('NEO', 'ICX'), ('NEO', 'REN'), ('NEO', 'SNT'), ('NEO', 'UTK'), ('NEO', 'XMR'), ('NULS', 'ONT'), ('ONT', 'EOS'), ('ONT', 'NULS'), ('PIVX', 'ARK'), ('PIVX', 'ELF'), ('PIVX', 'LSK'), ('PIVX', 'STEEM'), ('PIVX', 'STRAX'), ('POWR', 'ARDR'), ('POWR', 'ARK'), ('POWR', 'BAT'), ('POWR', 'GLM'), ('POWR', 'SYS'), ('PRO', 'ARDR'), ('PRO', 'BAT'), ('PRO', 'WAXP'), ('QTUM', 'ARDR'), ('QTUM', 'IOTA'), ('QTUM', 'TRX'), ('QTUM', 'ZEC'), ('REN', 'GNO'), ('REN', 'LINK'), ('REN', 'LRC'), ('REN', 'NEO'), ('REN', 'SNX'), ('REQ', 'BLZ'), ('REQ', 'GLM'), ('REQ', 'ICX'), ('REQ', 'MDT'), ('REQ', 'SYS'), ('RVN', 'ARDR'), ('RVN', 'BNB'), ('RVN', 'GAS'), ('RVN', 'IOST'), ('SBD', 'ADA'), ('SBD', 'ADX'), ('SBD', 'BORG'), ('SBD', 'BTC'), ('SBD', 'ZIL'), ('SNT', 'ADX'), ('SNT', 'ICX'), ('SNT', 'UTK'), ('SNT', 'XVG'), ('SNT', 'ZIL'), ('SNX', 'BTC'), ('SNX', 'GNO'), ('SNX', 'LINK'), ('SNX', 'LRC'), ('SNX', 'REN'), ('STEEM', 'ELF'), ('STEEM', 'LSK'), ('STEEM', 'PIVX'), ('STEEM', 'STRAX'), ('STMX', 'DENT'), ('STMX', 'MANA'), ('STMX', 'MED'), ('STMX', 'THETA'), ('STRAX', 'ARK'), ('STRAX', 'ELF'), ('STRAX', 'LSK'), ('STRAX', 'PIVX'), ('STRAX', 'STEEM'), ('SYS', 'ADX'), ('SYS', 'BLZ'), ('SYS', 'GLM'), ('SYS', 'REQ'), ('SYS', 'UTK'), ('THETA', 'ADX'), ('THETA', 'ENJ'), ('THETA', 'MANA'), ('THETA', 'MDT'), ('THETA', 'MED'), ('TRAC', 'ADX'), ('TRAC', 'BLZ'), ('TRAC', 'MDT'), ('TRAC', 'UTK'), ('TRAC', 'XDC'), ('TRX', 'NEO'), ('TRX', 'QTUM'), ( ...
# Number of pairs to be traded: 312
# Pairs Updated date: 2021-07-01
# Final pairs to be traded: [('ADA', 'DCR'), ('ADA', 'GNO'), ('ADA', 'MKR'), ('ADA', 'XNO'), ('ADA', 'ZEN'), ('ADX', 'ARK'), ('ADX', 'CVC'), ('ADX', 'GLM'), ('ADX', 'REQ'), ('ADX', 'ZIL'), ('AMB', 'MDT'), ('AMB', 'RVN'), ('AMB', 'VIB'), ('AMB', 'WAXP'), ('ANT', 'BLZ'), ('ANT', 'IDEX'), ('ANT', 'NMR'), ('ANT', 'OMG'), ('ANT', 'UTK'), ('ARDR', 'ARK'), ('ARDR', 'BAT'), ('ARDR', 'ELF'), ('ARDR', 'IOTA'), ('ARDR', 'STEEM'), ('ARK', 'ARDR'), ('ARK', 'ELF'), ('ARK', 'GLM'), ('ARK', 'POWR'), ('ARK', 'REQ'), ('BAT', 'ARDR'), ('BAT', 'ARK'), ('BAT', 'ELF'), ('BAT', 'ENJ'), ('BAT', 'IOTA'), ('BCH', 'DASH'), ('BCH', 'LTC'), ('BCH', 'NEO'), ('BCH', 'QTUM'), ('BCH', 'ZEC'), ('BLZ', 'GLM'), ('BLZ', 'POWR'), ('BLZ', 'REQ'), ('BLZ', 'TRAC'), ('BLZ', 'UTK'), ('BNB', 'MANA'), ('BNB', 'NEO'), ('BNB', 'TRX'), ('BNB', 'XDC'), ('BNB', 'ZEN'), ('BORG', 'BTC'), ('BORG', 'CVC'), ('BORG', 'DCR'), ('BORG', 'FUN'), ('BORG', 'ZIL'), ('BTC', 'BORG'), ('BTC', 'CVC'), ('BTC', 'FUN'), ('BTC', 'XLM'), ('BTC', 'ZIL'), ('BTG', 'BNB'), ('BTG', 'QTUM'), ('BTG', 'TRX'), ('BTG', 'XDC'), ('BTG', 'XRP'), ('CTXC', 'ARDR'), ('CTXC', 'BAT'), ('CTXC', 'ELF'), ('CTXC', 'NULS'), ('CTXC', 'VIB'), ('CVC', 'ADX'), ('CVC', 'DCR'), ('CVC', 'ICX'), ('CVC', 'IOST'), ('CVC', 'ZIL'), ('DASH', 'BCH'), ('DASH', 'IOTA'), ('DASH', 'LTC'), ('DASH', 'STRAX'), ('DASH', 'ZEC'), ('DCR', 'ADX'), ('DCR', 'CVC'), ('DCR', 'IOST'), ('DCR', 'IOTA'), ('DCR', 'ZIL'), ('DENT', 'MED'), ('DENT', 'MTL'), ('DENT', 'STEEM'), ('DENT', 'STMX'), ('DENT', 'STORJ'), ('DGB', 'IOTA'), ('DGB', 'NEO'), ('DGB', 'XMR'), ('DGB', 'XVG'), ('DGB', 'ZEC'), ('DOGE', 'ETC'), ('DOGE', 'MKR'), ('DOGE', 'ZEN'), ('ELF', 'ARDR'), ('ELF', 'ARK'), ('ELF', 'BAT'), ('ELF', 'PIVX'), ('ELF', 'POWR'), ('ENJ', 'ARDR'), ('ENJ', 'BAT'), ('ENJ', 'MANA'), ('ENJ', 'THETA'), ('ENJ', 'WAXP'), ('EOS', 'BCH'), ('EOS', 'ONT'), ('EOS', 'QTUM'), ('ETC', 'DOGE'), ('FUN', 'BORG'), ('FUN', 'BTC'), ('FUN', 'CVC'), ('FUN', 'ZIL'), ('FUN', 'ZRX'), ('GAS', 'ARK'), ('GAS', 'BAT'), ('GAS', 'IOST'), ('GAS', 'IOTA'), ('GAS', 'PIVX'), ('GFT', 'ARDR'), ('GFT', 'TRX'), ('GLM', 'ADX'), ('GLM', 'ARK'), ('GLM', 'ICX'), ('GLM', 'POWR'), ('GLM', 'REQ'), ('GNO', 'LINK'), ('GNO', 'MKR'), ('GNO', 'WAVES'), ('GNO', 'XLM'), ('GNO', 'XMR'), ('ICX', 'CVC'), ('ICX', 'GLM'), ('ICX', 'POWR'), ('ICX', 'REQ'), ('ICX', 'ZRX'), ('IDEX', 'ANT'), ('IDEX', 'BLZ'), ('IOST', 'CVC'), ('IOST', 'DCR'), ('IOST', 'GAS'), ('IOST', 'ICX'), ('IOST', 'IOTA'), ('IOTA', 'BAT'), ('IOTA', 'CVC'), ('IOTA', 'DCR'), ('IOTA', 'IOST'), ('IOTA', 'XVG'), ('LINK', 'GNO'), ('LINK', 'LRC'), ('LINK', 'OMG'), ('LINK', 'UTK'), ('LINK', 'XLM'), ('LRC', 'BTC'), ('LRC', 'FUN'), ('LRC', 'LINK'), ('LRC', 'REN'), ('LRC', 'SNX'), ('LSK', 'ARDR'), ('LSK', 'BAT'), ('LSK', 'SNT'), ('LSK', 'STEEM'), ('LSK', 'STRAX'), ('LTC', 'BCH'), ('LTC', 'DASH'), ('LTC', 'XLM'), ('LTC', 'ZEC'), ('LTC', 'ZIL'), ('MANA', 'BAT'), ('MANA', 'BNB'), ('MANA', 'ENJ'), ('MANA', 'THETA'), ('MANA', 'XVG'), ('MDT', 'BLZ'), ('MDT', 'GLM'), ('MDT', 'REQ'), ('MDT', 'TRAC'), ('MDT', 'ZIL'), ('MED', 'DENT'), ('MED', 'MTL'), ('MED', 'STEEM'), ('MED', 'STMX'), ('MED', 'STORJ'), ('MKR', 'BNB'), ('MKR', 'GNO'), ('MKR', 'NEO'), ('MKR', 'XNO'), ('MKR', 'ZEN'), ('MLN', 'GNO'), ('MLN', 'LINK'), ('MLN', 'OMG'), ('MLN', 'UQC'), ('MLN', 'XMR'), ('MTL', 'ARDR'), ('MTL', 'DENT'), ('MTL', 'MED'), ('MTL', 'STEEM'), ('MTL', 'STORJ'), ('NEO', 'DGB'), ('NEO', 'QTUM'), ('NEO', 'TRX'), ('NEO', 'XVG'), ('NEO', 'ZEC'), ('NMR', 'ANT'), ('NMR', 'OMG'), ('NULS', 'CTXC'), ('NULS', 'ELF'), ('NULS', 'ONT'), ('NULS', 'VIB'), ('OMG', 'ANT'), ('OMG', 'GNO'), ('OMG', 'LINK'), ('OMG', 'UTK'), ('OMG', 'XMR'), ('ONT', 'CTXC'), ('ONT', 'EOS'), ('ONT', 'LSK'), ('ONT', 'NULS'), ('ONT', 'STEEM'), ('PIVX', 'ARDR'), ('PIVX', 'ARK'), ('PIVX', 'ELF'), ('PIVX', 'IOST'), ('PIVX', 'POWR'), ('POWR', 'ARDR'), ('POWR', 'ARK'), ('POWR', 'ELF'), ('POWR', 'GLM'), ('POWR', 'ICX'), ('PRO', 'BNB'), ('PRO', 'MANA'), ('PRO', 'QTUM'), ('PRO', 'STRAX'), ('PRO', 'SYS'), ('QTUM', 'BTG'), ('QTUM', 'NEO'), ('QTUM',  ...
# Number of pairs to be traded: 399
# Pairs Updated date: 2021-10-01
# Final pairs to be traded: [('ADA', 'BNB'), ('ADA', 'GNO'), ('ADA', 'STRAX'), ('ADA', 'WAVES'), ('ADA', 'XDC'), ('ADX', 'BLZ'), ('ADX', 'MDT'), ('ADX', 'PIVX'), ('ADX', 'SNT'), ('ADX', 'ZIL'), ('AMB', 'BLZ'), ('AMB', 'MDT'), ('AMB', 'NULS'), ('AMB', 'VIB'), ('ANT', 'BLZ'), ('ANT', 'NMR'), ('ANT', 'TRAC'), ('ANT', 'UTK'), ('ARDR', 'ARK'), ('ARDR', 'BAT'), ('ARDR', 'CVC'), ('ARDR', 'IOTA'), ('ARDR', 'POWR'), ('ARK', 'ARDR'), ('ARK', 'BAT'), ('ARK', 'ICX'), ('ARK', 'POWR'), ('ARK', 'STEEM'), ('BAT', 'ARK'), ('BAT', 'ENJ'), ('BAT', 'IOTA'), ('BAT', 'STEEM'), ('BAT', 'XVG'), ('BCH', 'DASH'), ('BCH', 'LTC'), ('BCH', 'NEO'), ('BCH', 'QTUM'), ('BCH', 'ZEC'), ('BLZ', 'ARK'), ('BLZ', 'ICX'), ('BLZ', 'MDT'), ('BLZ', 'TRAC'), ('BLZ', 'UTK'), ('BNB', 'BTG'), ('BNB', 'MANA'), ('BNB', 'STRAX'), ('BNB', 'TRX'), ('BNB', 'ZEN'), ('BORG', 'BTC'), ('BORG', 'DCR'), ('BORG', 'FUN'), ('BORG', 'UTK'), ('BORG', 'ZIL'), ('BTC', 'BORG'), ('BTC', 'CVC'), ('BTC', 'DCR'), ('BTC', 'XLM'), ('BTC', 'ZIL'), ('BTG', 'BNB'), ('BTG', 'MANA'), ('BTG', 'QTUM'), ('BTG', 'TRX'), ('BTG', 'XRP'), ('CTXC', 'BAT'), ('CTXC', 'ICX'), ('CTXC', 'IOTA'), ('CTXC', 'SNT'), ('CTXC', 'XVG'), ('CVC', 'ARDR'), ('CVC', 'ARK'), ('CVC', 'ICX'), ('CVC', 'IOST'), ('CVC', 'IOTA'), ('DASH', 'BCH'), ('DASH', 'IOTA'), ('DASH', 'LSK'), ('DASH', 'LTC'), ('DASH', 'ZEC'), ('DCR', 'BNB'), ('DCR', 'BORG'), ('DCR', 'BTC'), ('DCR', 'GAS'), ('DCR', 'SBD'), ('DENT', 'MED'), ('DENT', 'MTL'), ('DENT', 'STEEM'), ('DENT', 'STMX'), ('DENT', 'STORJ'), ('DGB', 'NEO'), ('DGB', 'SNT'), ('DGB', 'XMR'), ('DGB', 'XVG'), ('DGB', 'ZEC'), ('DOGE', 'BNB'), ('DOGE', 'BTG'), ('DOGE', 'ETC'), ('DOGE', 'MKR'), ('DOGE', 'ZEN'), ('ELF', 'IOST'), ('ENJ', 'ARDR'), ('ENJ', 'BAT'), ('ENJ', 'GAS'), ('ENJ', 'MANA'), ('ENJ', 'THETA'), ('EOS', 'BCH'), ('EOS', 'ONT'), ('EOS', 'QTUM'), ('ETC', 'DOGE'), ('ETC', 'RLC'), ('FUN', 'BORG'), ('FUN', 'BTC'), ('FUN', 'XLM'), ('FUN', 'ZIL'), ('FUN', 'ZRX'), ('GAS', 'ARK'), ('GAS', 'BAT'), ('GAS', 'DCR'), ('GAS', 'ENJ'), ('GAS', 'IOTA'), ('GFT', 'BAT'), ('GFT', 'SNT'), ('GFT', 'THETA'), ('GFT', 'TRX'), ('GFT', 'XVG'), ('GLM', 'ARDR'), ('GLM', 'ARK'), ('GLM', 'CVC'), ('GLM', 'DCR'), ('GLM', 'POWR'), ('GNO', 'ADA'), ('GNO', 'MKR'), ('GNO', 'MLN'), ('GNO', 'STRAX'), ('GNO', 'WAVES'), ('ICX', 'ARK'), ('ICX', 'CVC'), ('ICX', 'IOTA'), ('ICX', 'POWR'), ('ICX', 'ZRX'), ('IOST', 'ARDR'), ('IOST', 'ARK'), ('IOST', 'CVC'), ('IOST', 'ICX'), ('IOST', 'IOTA'), ('IOTA', 'ARDR'), ('IOTA', 'BAT'), ('IOTA', 'CVC'), ('IOTA', 'ICX'), ('IOTA', 'IOST'), ('LINK', 'LTC'), ('LINK', 'UTK'), ('LINK', 'XLM'), ('LINK', 'XMR'), ('LINK', 'ZEC'), ('LRC', 'BTC'), ('LRC', 'FUN'), ('LRC', 'LINK'), ('LRC', 'REN'), ('LRC', 'SNX'), ('LSK', 'BAT'), ('LSK', 'QTUM'), ('LSK', 'SNT'), ('LSK', 'STEEM'), ('LSK', 'XVG'), ('LTC', 'BCH'), ('LTC', 'DASH'), ('LTC', 'XLM'), ('LTC', 'ZEC'), ('LTC', 'ZIL'), ('MANA', 'BAT'), ('MANA', 'BNB'), ('MANA', 'ENJ'), ('MANA', 'THETA'), ('MANA', 'XVG'), ('MDT', 'ADX'), ('MDT', 'BLZ'), ('MDT', 'TRAC'), ('MDT', 'ZIL'), ('MDT', 'ZRX'), ('MED', 'DENT'), ('MED', 'MTL'), ('MED', 'STEEM'), ('MED', 'STMX'), ('MED', 'STORJ'), ('MKR', 'BNB'), ('MKR', 'DCR'), ('MKR', 'XMR'), ('MKR', 'XNO'), ('MKR', 'ZEN'), ('MLN', 'GNO'), ('MLN', 'STRAX'), ('MLN', 'TRX'), ('MLN', 'WAVES'), ('MTL', 'ARDR'), ('MTL', 'ARK'), ('MTL', 'MED'), ('MTL', 'STEEM'), ('MTL', 'STORJ'), ('NEO', 'DGB'), ('NEO', 'QTUM'), ('NEO', 'XMR'), ('NEO', 'XVG'), ('NEO', 'ZEC'), ('NMR', 'ANT'), ('NULS', 'BAT'), ('NULS', 'CTXC'), ('NULS', 'ONT'), ('NULS', 'PIVX'), ('NULS', 'VIB'), ('OMG', 'LINK'), ('OMG', 'TRX'), ('OMG', 'UTK'), ('OMG', 'XMR'), ('ONT', 'BAT'), ('ONT', 'LSK'), ('ONT', 'NULS'), ('ONT', 'PIVX'), ('ONT', 'VIB'), ('PIVX', 'ADX'), ('PIVX', 'BAT'), ('PIVX', 'ICX'), ('PIVX', 'SNT'), ('PIVX', 'STEEM'), ('POWR', 'ARDR'), ('POWR', 'ARK'), ('POWR', 'BAT'), ('POWR', 'GLM'), ('POWR', 'ICX'), ('PRO', 'SYS'), ('QTUM', 'BNB'), ('QTUM', 'BTG'), ('QTUM', 'NEO'), ('QTUM', 'TRX'), ('QTUM', 'XRP'), ('REN', 'ICX'), ('REN', 'LRC'), ('REN', 'SNX'), ('REN', 'TRAC'), ('R ...
# Number of pairs to be traded: 386
# Pairs Updated date: 2022-01-01
# Final pairs to be traded: [('ADA', 'GLM'), ('ADA', 'MLN'), ('ADA', 'STRAX'), ('ADA', 'WAVES'), ('ADA', 'XDC'), ('ADX', 'BLZ'), ('ADX', 'SNT'), ('ADX', 'VIB'), ('ADX', 'ZIL'), ('ADX', 'ZRX'), ('AMB', 'BLZ'), ('AMB', 'PIVX'), ('AMB', 'VIB'), ('ARDR', 'ARK'), ('ARDR', 'CVC'), ('ARDR', 'IOTA'), ('ARDR', 'MTL'), ('ARDR', 'TRX'), ('ARK', 'ARDR'), ('ARK', 'CVC'), ('ARK', 'ICX'), ('ARK', 'IOTA'), ('ARK', 'STEEM'), ('BAT', 'BNB'), ('BAT', 'ENJ'), ('BAT', 'POWR'), ('BAT', 'STORJ'), ('BAT', 'ZEC'), ('BCH', 'DASH'), ('BCH', 'EOS'), ('BCH', 'LTC'), ('BCH', 'NEO'), ('BCH', 'XNO'), ('BLZ', 'ADX'), ('BLZ', 'ARK'), ('BLZ', 'ICX'), ('BLZ', 'IOTA'), ('BLZ', 'UTK'), ('BNB', 'ENJ'), ('BNB', 'GLM'), ('BNB', 'QTUM'), ('BNB', 'TRX'), ('BNB', 'ZEN'), ('BORG', 'DCR'), ('BORG', 'FUN'), ('BORG', 'UTK'), ('BORG', 'XLM'), ('BORG', 'ZIL'), ('BTC', 'CVC'), ('BTC', 'GLM'), ('BTC', 'ICX'), ('BTC', 'LTC'), ('BTC', 'UTK'), ('BTG', 'QTUM'), ('BTG', 'STRAX'), ('BTG', 'TRX'), ('BTG', 'XRP'), ('BTG', 'ZEN'), ('CVC', 'ARDR'), ('CVC', 'ARK'), ('CVC', 'ICX'), ('CVC', 'IOST'), ('CVC', 'IOTA'), ('DASH', 'BCH'), ('DASH', 'LSK'), ('DASH', 'LTC'), ('DASH', 'NEO'), ('DASH', 'XVG'), ('DCR', 'BORG'), ('DCR', 'GAS'), ('DCR', 'SBD'), ('DCR', 'THETA'), ('DCR', 'ZIL'), ('DENT', 'ARK'), ('DENT', 'MED'), ('DENT', 'MTL'), ('DENT', 'STEEM'), ('DENT', 'STMX'), ('DGB', 'DASH'), ('DGB', 'NEO'), ('DGB', 'SNT'), ('DGB', 'XVG'), ('DGB', 'ZIL'), ('DOGE', 'BTG'), ('DOGE', 'ETC'), ('DOGE', 'MKR'), ('DOGE', 'RLC'), ('DOGE', 'ZEN'), ('ELF', 'ARDR'), ('ELF', 'CVC'), ('ELF', 'GLM'), ('ELF', 'IOST'), ('ENJ', 'BAT'), ('ENJ', 'BNB'), ('ENJ', 'GLM'), ('ENJ', 'POWR'), ('ENJ', 'STORJ'), ('EOS', 'BCH'), ('EOS', 'ONT'), ('ETC', 'DOGE'), ('ETC', 'RLC'), ('FUN', 'BORG'), ('FUN', 'SNX'), ('FUN', 'XLM'), ('FUN', 'ZIL'), ('FUN', 'ZRX'), ('GAS', 'ARK'), ('GAS', 'DCR'), ('GAS', 'IOTA'), ('GAS', 'RVN'), ('GAS', 'THETA'), ('GFT', 'BAT'), ('GFT', 'TRX'), ('GLM', 'ARDR'), ('GLM', 'ARK'), ('GLM', 'BTC'), ('GLM', 'CVC'), ('GLM', 'POWR'), ('GNO', 'BNB'), ('GNO', 'WAXP'), ('ICX', 'ARDR'), ('ICX', 'ARK'), ('ICX', 'CVC'), ('ICX', 'IOST'), ('ICX', 'IOTA'), ('IOST', 'ARDR'), ('IOST', 'ARK'), ('IOST', 'CVC'), ('IOST', 'ICX'), ('IOST', 'IOTA'), ('IOTA', 'ARDR'), ('IOTA', 'ARK'), ('IOTA', 'CVC'), ('IOTA', 'ICX'), ('IOTA', 'IOST'), ('LINK', 'LTC'), ('LINK', 'UTK'), ('LINK', 'XLM'), ('LINK', 'XMR'), ('LINK', 'ZIL'), ('LRC', 'MANA'), ('LSK', 'DASH'), ('LSK', 'GAS'), ('LSK', 'SNT'), ('LSK', 'STEEM'), ('LSK', 'XVG'), ('LTC', 'DASH'), ('LTC', 'LINK'), ('LTC', 'XLM'), ('LTC', 'XMR'), ('LTC', 'ZIL'), ('MANA', 'LRC'), ('MANA', 'WAXP'), ('MED', 'ARK'), ('MED', 'DENT'), ('MED', 'MTL'), ('MED', 'STEEM'), ('MED', 'STMX'), ('MKR', 'DOGE'), ('MKR', 'UQC'), ('MKR', 'XMR'), ('MKR', 'XNO'), ('MKR', 'ZEN'), ('MLN', 'ADA'), ('MLN', 'GLM'), ('MLN', 'STRAX'), ('MLN', 'TRX'), ('MLN', 'WAVES'), ('MTL', 'ARDR'), ('MTL', 'ARK'), ('MTL', 'MED'), ('MTL', 'STEEM'), ('MTL', 'TRX'), ('NEO', 'BCH'), ('NEO', 'DGB'), ('NEO', 'XMR'), ('NEO', 'XNO'), ('NEO', 'XVG'), ('NULS', 'VIB'), ('ONT', 'DASH'), ('ONT', 'EOS'), ('ONT', 'LSK'), ('ONT', 'PIVX'), ('ONT', 'VIB'), ('PIVX', 'ONT'), ('PIVX', 'SNT'), ('PIVX', 'VIB'), ('PIVX', 'ZIL'), ('PIVX', 'ZRX'), ('POWR', 'ARK'), ('POWR', 'BAT'), ('POWR', 'ENJ'), ('POWR', 'GLM'), ('POWR', 'STORJ'), ('PRO', 'TRAC'), ('QTUM', 'BTG'), ('QTUM', 'STRAX'), ('QTUM', 'TRX'), ('QTUM', 'XRP'), ('QTUM', 'ZEN'), ('REN', 'BTC'), ('REN', 'CVC'), ('REN', 'ICX'), ('REN', 'LINK'), ('REN', 'UTK'), ('RLC', 'DOGE'), ('RLC', 'ETC'), ('RLC', 'QTUM'), ('RVN', 'ARK'), ('RVN', 'GAS'), ('RVN', 'ICX'), ('RVN', 'IOST'), ('RVN', 'IOTA'), ('SBD', 'ARDR'), ('SBD', 'CVC'), ('SBD', 'DCR'), ('SBD', 'GAS'), ('SBD', 'THETA'), ('SNT', 'IOTA'), ('SNT', 'LSK'), ('SNT', 'STEEM'), ('SNT', 'XVG'), ('SNT', 'ZIL'), ('SNX', 'FUN'), ('STEEM', 'ARK'), ('STEEM', 'LSK'), ('STEEM', 'MED'), ('STEEM', 'SNT'), ('STEEM', 'STMX'), ('STMX', 'ARK'), ('STMX', 'DENT'), ('STMX', 'MED'), ('STMX', 'STEEM'), ('STMX', 'THETA'), ('STORJ', 'ARDR'), ('STORJ', 'ARK'), ('STORJ', 'BAT'), ('STORJ', ...
# Number of pairs to be traded: 336
# Pairs Updated date: 2022-04-01
# Final pairs to be traded: [('ADA', 'MLN'), ('ADA', 'STRAX'), ('ADA', 'XDC'), ('ADX', 'BLZ'), ('ADX', 'SNT'), ('ADX', 'VIB'), ('ADX', 'ZIL'), ('ADX', 'ZRX'), ('AMB', 'PIVX'), ('AMB', 'VIB'), ('ARDR', 'ARK'), ('ARDR', 'CVC'), ('ARDR', 'IOTA'), ('ARDR', 'MTL'), ('ARDR', 'TRX'), ('ARK', 'ARDR'), ('ARK', 'CVC'), ('ARK', 'ICX'), ('ARK', 'IOTA'), ('ARK', 'STEEM'), ('BAT', 'ARDR'), ('BAT', 'BNB'), ('BAT', 'ENJ'), ('BAT', 'IOTA'), ('BAT', 'STORJ'), ('BCH', 'DASH'), ('BCH', 'EOS'), ('BCH', 'NEO'), ('BCH', 'XNO'), ('BCH', 'XVG'), ('BLZ', 'ADX'), ('BLZ', 'ARK'), ('BLZ', 'ICX'), ('BLZ', 'IOTA'), ('BLZ', 'UTK'), ('BNB', 'BAT'), ('BNB', 'ENJ'), ('BNB', 'GLM'), ('BNB', 'TRX'), ('BNB', 'XRP'), ('BORG', 'DCR'), ('BORG', 'FUN'), ('BORG', 'UTK'), ('BORG', 'XLM'), ('BORG', 'ZIL'), ('BTC', 'ARDR'), ('BTC', 'CVC'), ('BTC', 'GLM'), ('BTC', 'LTC'), ('BTG', 'QTUM'), ('BTG', 'STRAX'), ('BTG', 'TRX'), ('BTG', 'XRP'), ('BTG', 'ZEN'), ('CVC', 'ARDR'), ('CVC', 'ARK'), ('CVC', 'BTC'), ('CVC', 'IOST'), ('CVC', 'IOTA'), ('DASH', 'BCH'), ('DASH', 'LSK'), ('DASH', 'NEO'), ('DASH', 'SNT'), ('DASH', 'XVG'), ('DCR', 'BORG'), ('DCR', 'GAS'), ('DCR', 'THETA'), ('DCR', 'XNO'), ('DCR', 'XVG'), ('DENT', 'ARK'), ('DENT', 'MED'), ('DENT', 'MTL'), ('DENT', 'STEEM'), ('DENT', 'STMX'), ('DGB', 'BCH'), ('DGB', 'DASH'), ('DGB', 'NEO'), ('DGB', 'ONT'), ('DGB', 'XVG'), ('DOGE', 'BTG'), ('DOGE', 'ETC'), ('DOGE', 'MKR'), ('DOGE', 'ZEN'), ('ELF', 'ARDR'), ('ENJ', 'BAT'), ('ENJ', 'BNB'), ('ENJ', 'GLM'), ('ENJ', 'STORJ'), ('ENJ', 'WAXP'), ('EOS', 'BCH'), ('EOS', 'DASH'), ('EOS', 'LSK'), ('EOS', 'NEO'), ('EOS', 'ONT'), ('ETC', 'DOGE'), ('ETC', 'RLC'), ('FUN', 'BORG'), ('FUN', 'SNX'), ('FUN', 'XLM'), ('FUN', 'ZIL'), ('FUN', 'ZRX'), ('GAS', 'DCR'), ('GAS', 'IOTA'), ('GAS', 'RVN'), ('GAS', 'STEEM'), ('GAS', 'THETA'), ('GLM', 'ARDR'), ('GLM', 'BNB'), ('GLM', 'BTC'), ('GLM', 'CVC'), ('GLM', 'ENJ'), ('GNO', 'BNB'), ('GNO', 'WAXP'), ('ICX', 'ARDR'), ('ICX', 'ARK'), ('ICX', 'CVC'), ('ICX', 'IOST'), ('ICX', 'IOTA'), ('IOST', 'ARDR'), ('IOST', 'ARK'), ('IOST', 'CVC'), ('IOST', 'ICX'), ('IOST', 'IOTA'), ('IOTA', 'ARDR'), ('IOTA', 'ARK'), ('IOTA', 'CVC'), ('IOTA', 'IOST'), ('IOTA', 'TRX'), ('LINK', 'DASH'), ('LINK', 'LTC'), ('LINK', 'UTK'), ('LINK', 'XLM'), ('LINK', 'XMR'), ('LSK', 'DASH'), ('LSK', 'ONT'), ('LSK', 'SNT'), ('LSK', 'STEEM'), ('LSK', 'XVG'), ('LTC', 'BCH'), ('LTC', 'DASH'), ('LTC', 'LINK'), ('LTC', 'XLM'), ('LTC', 'XMR'), ('MANA', 'WAXP'), ('MED', 'ARK'), ('MED', 'DENT'), ('MED', 'MTL'), ('MED', 'STEEM'), ('MED', 'STMX'), ('MKR', 'DOGE'), ('MKR', 'UQC'), ('MKR', 'XMR'), ('MKR', 'XNO'), ('MKR', 'ZEN'), ('MLN', 'ADA'), ('MTL', 'ARDR'), ('MTL', 'ARK'), ('MTL', 'DENT'), ('MTL', 'MED'), ('MTL', 'TRX'), ('NEO', 'BCH'), ('NEO', 'DASH'), ('NEO', 'DGB'), ('NEO', 'XNO'), ('NEO', 'XVG'), ('ONT', 'DGB'), ('ONT', 'LSK'), ('ONT', 'PIVX'), ('ONT', 'SNT'), ('ONT', 'VIB'), ('PIVX', 'DGB'), ('PIVX', 'ONT'), ('PIVX', 'SNT'), ('PIVX', 'VIB'), ('PIVX', 'ZRX'), ('QTUM', 'BTG'), ('QTUM', 'STRAX'), ('QTUM', 'TRX'), ('QTUM', 'XRP'), ('QTUM', 'ZEN'), ('REN', 'ICX'), ('RLC', 'ETC'), ('RVN', 'ARK'), ('RVN', 'GAS'), ('RVN', 'ICX'), ('RVN', 'IOTA'), ('RVN', 'UTK'), ('SBD', 'ARDR'), ('SBD', 'CVC'), ('SBD', 'DCR'), ('SBD', 'GAS'), ('SBD', 'THETA'), ('SNT', 'LSK'), ('SNT', 'STEEM'), ('SNT', 'VIB'), ('SNT', 'XVG'), ('SNT', 'ZIL'), ('SNX', 'FUN'), ('STEEM', 'ARK'), ('STEEM', 'LSK'), ('STEEM', 'MED'), ('STEEM', 'SNT'), ('STEEM', 'STMX'), ('STMX', 'ARK'), ('STMX', 'DENT'), ('STMX', 'MED'), ('STMX', 'STEEM'), ('STMX', 'THETA'), ('STORJ', 'ARDR'), ('STORJ', 'ARK'), ('STORJ', 'BAT'), ('STORJ', 'ENJ'), ('STORJ', 'GLM'), ('STRAX', 'ARDR'), ('STRAX', 'BTG'), ('STRAX', 'QTUM'), ('STRAX', 'TRX'), ('STRAX', 'ZEN'), ('THETA', 'DCR'), ('THETA', 'GAS'), ('THETA', 'SBD'), ('THETA', 'STMX'), ('THETA', 'XVG'), ('TRX', 'ARDR'), ('TRX', 'BTG'), ('TRX', 'IOTA'), ('TRX', 'QTUM'), ('TRX', 'XRP'), ('UQC', 'BTG'), ('UQC', 'MKR'), ('UQC', 'THETA'), ('UQC', 'XMR'), ('UQC', 'ZEN'), ('UTK', 'BLZ'), ('UTK', 'IOTA'), ('UTK', 'LINK'), ('UTK', 'ZIL ...
# Number of pairs to be traded: 295
# Pairs Updated date: 2022-07-01
# Final pairs to be traded: [('ADA', 'XDC'), ('ADX', 'SNT'), ('ADX', 'VIB'), ('ADX', 'XVG'), ('ADX', 'ZRX'), ('AMB', 'PIVX'), ('AMB', 'VIB'), ('ARDR', 'ARK'), ('ARDR', 'CVC'), ('ARDR', 'IOST'), ('ARDR', 'IOTA'), ('ARDR', 'MTL'), ('ARK', 'ARDR'), ('ARK', 'CVC'), ('ARK', 'ICX'), ('ARK', 'IOTA'), ('ARK', 'STEEM'), ('BAT', 'ENJ'), ('BAT', 'STORJ'), ('BCH', 'DASH'), ('BCH', 'EOS'), ('BCH', 'NEO'), ('BCH', 'XNO'), ('BCH', 'XVG'), ('BLZ', 'ARK'), ('BLZ', 'ICX'), ('BLZ', 'STMX'), ('BLZ', 'UTK'), ('BLZ', 'VIB'), ('BNB', 'ENJ'), ('BNB', 'GLM'), ('BNB', 'TRX'), ('BORG', 'DCR'), ('BORG', 'FUN'), ('BORG', 'GAS'), ('BORG', 'RVN'), ('BORG', 'UTK'), ('BTC', 'CVC'), ('BTG', 'QTUM'), ('BTG', 'STRAX'), ('BTG', 'XMR'), ('BTG', 'XRP'), ('BTG', 'ZEN'), ('CVC', 'ARDR'), ('CVC', 'ARK'), ('CVC', 'BTC'), ('CVC', 'IOST'), ('CVC', 'IOTA'), ('DASH', 'BCH'), ('DASH', 'DGB'), ('DASH', 'LINK'), ('DASH', 'LTC'), ('DASH', 'XVG'), ('DCR', 'BORG'), ('DCR', 'GAS'), ('DCR', 'THETA'), ('DCR', 'XNO'), ('DCR', 'XVG'), ('DENT', 'ARK'), ('DENT', 'MED'), ('DENT', 'MTL'), ('DENT', 'STEEM'), ('DENT', 'STMX'), ('DGB', 'BCH'), ('DGB', 'DASH'), ('DGB', 'NEO'), ('DGB', 'ONT'), ('DGB', 'XVG'), ('DOGE', 'ETC'), ('DOGE', 'MKR'), ('ENJ', 'BAT'), ('ENJ', 'BNB'), ('ENJ', 'STORJ'), ('EOS', 'BCH'), ('EOS', 'DASH'), ('EOS', 'DGB'), ('EOS', 'NEO'), ('EOS', 'ONT'), ('ETC', 'DOGE'), ('FUN', 'BORG'), ('FUN', 'XLM'), ('FUN', 'ZRX'), ('GAS', 'DCR'), ('GAS', 'IOTA'), ('GAS', 'RVN'), ('GAS', 'STEEM'), ('GAS', 'THETA'), ('GLM', 'ARDR'), ('GLM', 'BNB'), ('GLM', 'CVC'), ('ICX', 'ARK'), ('ICX', 'CVC'), ('ICX', 'IOST'), ('ICX', 'IOTA'), ('ICX', 'UTK'), ('IOST', 'ARDR'), ('IOST', 'ARK'), ('IOST', 'CVC'), ('IOST', 'ICX'), ('IOST', 'IOTA'), ('IOTA', 'ARDR'), ('IOTA', 'ARK'), ('IOTA', 'CVC'), ('IOTA', 'ICX'), ('IOTA', 'IOST'), ('LINK', 'BCH'), ('LINK', 'DASH'), ('LINK', 'LTC'), ('LINK', 'XLM'), ('LINK', 'XNO'), ('LSK', 'DASH'), ('LSK', 'GAS'), ('LSK', 'SNT'), ('LSK', 'STEEM'), ('LSK', 'XVG'), ('LTC', 'BCH'), ('LTC', 'DASH'), ('LTC', 'LINK'), ('LTC', 'XLM'), ('LTC', 'XVG'), ('MED', 'ARK'), ('MED', 'DENT'), ('MED', 'MTL'), ('MED', 'STEEM'), ('MED', 'STMX'), ('MKR', 'BTG'), ('MKR', 'DOGE'), ('MKR', 'XMR'), ('MKR', 'XNO'), ('MKR', 'ZEN'), ('MTL', 'ARDR'), ('MTL', 'ARK'), ('MTL', 'MED'), ('MTL', 'STEEM'), ('MTL', 'TRX'), ('NEO', 'BCH'), ('NEO', 'DASH'), ('NEO', 'DGB'), ('NEO', 'XNO'), ('NEO', 'XVG'), ('NMR', 'ONT'), ('ONT', 'DGB'), ('ONT', 'EOS'), ('ONT', 'LSK'), ('ONT', 'PIVX'), ('ONT', 'XVG'), ('PIVX', 'AMB'), ('PIVX', 'DASH'), ('PIVX', 'DGB'), ('PIVX', 'ONT'), ('PIVX', 'VIB'), ('QTUM', 'ARDR'), ('QTUM', 'BTG'), ('QTUM', 'STRAX'), ('QTUM', 'XRP'), ('QTUM', 'ZEN'), ('REN', 'ICX'), ('RVN', 'ARK'), ('RVN', 'GAS'), ('RVN', 'ICX'), ('RVN', 'IOTA'), ('RVN', 'UTK'), ('SBD', 'ARDR'), ('SBD', 'ARK'), ('SBD', 'DCR'), ('SBD', 'GAS'), ('SBD', 'THETA'), ('SNT', 'DASH'), ('SNT', 'LSK'), ('SNT', 'STEEM'), ('SNT', 'VIB'), ('SNT', 'XVG'), ('STEEM', 'ARK'), ('STEEM', 'LSK'), ('STEEM', 'MED'), ('STEEM', 'SNT'), ('STEEM', 'STMX'), ('STMX', 'ARK'), ('STMX', 'DENT'), ('STMX', 'MED'), ('STMX', 'STEEM'), ('STMX', 'THETA'), ('STORJ', 'ARK'), ('STORJ', 'BAT'), ('STORJ', 'ENJ'), ('STRAX', 'ARDR'), ('STRAX', 'BTG'), ('STRAX', 'IOTA'), ('STRAX', 'QTUM'), ('STRAX', 'ZEN'), ('THETA', 'DCR'), ('THETA', 'GAS'), ('THETA', 'SBD'), ('THETA', 'STMX'), ('THETA', 'XVG'), ('TRX', 'ARDR'), ('TRX', 'BNB'), ('TRX', 'BTG'), ('TRX', 'MTL'), ('TRX', 'QTUM'), ('UQC', 'ZEN'), ('UTK', 'BLZ'), ('UTK', 'ICX'), ('UTK', 'IOTA'), ('UTK', 'RVN'), ('UTK', 'ZRX'), ('VGX', 'BORG'), ('VGX', 'RVN'), ('VIB', 'ADX'), ('VIB', 'PIVX'), ('VIB', 'SNT'), ('VIB', 'XVG'), ('VIB', 'ZRX'), ('XDC', 'ADA'), ('XLM', 'DASH'), ('XLM', 'LINK'), ('XLM', 'LTC'), ('XLM', 'SNT'), ('XLM', 'XNO'), ('XMR', 'BTG'), ('XMR', 'MKR'), ('XMR', 'ZEN'), ('XNO', 'BCH'), ('XNO', 'DCR'), ('XNO', 'NEO'), ('XNO', 'XLM'), ('XNO', 'XVG'), ('XRP', 'BTG'), ('XRP', 'QTUM'), ('XVG', 'DASH'), ('XVG', 'DGB'), ('XVG', 'LSK'), ('XVG', 'NEO'), ('XVG', 'SNT'), ('ZEN', 'BTG'), ('ZEN', 'MKR'), ('ZEN', 'QTUM'), ('ZE ...
# Number of pairs to be traded: 246
# Pairs Updated date: 2022-10-01
# Final pairs to be traded: [('ADA', 'XDC'), ('ADX', 'ONT'), ('ADX', 'PIVX'), ('ADX', 'SNT'), ('ADX', 'XVG'), ('ADX', 'ZRX'), ('AMB', 'ADX'), ('AMB', 'BLZ'), ('AMB', 'PIVX'), ('ARDR', 'ARK'), ('ARDR', 'CVC'), ('ARDR', 'IOST'), ('ARDR', 'MTL'), ('ARDR', 'STEEM'), ('ARK', 'ARDR'), ('ARK', 'CVC'), ('ARK', 'ICX'), ('ARK', 'IOTA'), ('ARK', 'STEEM'), ('BAT', 'ENJ'), ('BAT', 'STORJ'), ('BCH', 'DASH'), ('BCH', 'EOS'), ('BCH', 'LINK'), ('BCH', 'LTC'), ('BCH', 'NEO'), ('BLZ', 'ARK'), ('BLZ', 'ICX'), ('BLZ', 'STEEM'), ('BLZ', 'STMX'), ('BLZ', 'UTK'), ('BORG', 'DCR'), ('BORG', 'FUN'), ('BORG', 'GAS'), ('BORG', 'UTK'), ('BORG', 'ZRX'), ('BTC', 'CVC'), ('BTC', 'ICX'), ('BTG', 'QTUM'), ('BTG', 'STRAX'), ('BTG', 'XMR'), ('BTG', 'XRP'), ('BTG', 'ZEN'), ('CVC', 'ARDR'), ('CVC', 'ARK'), ('CVC', 'ICX'), ('CVC', 'IOST'), ('CVC', 'IOTA'), ('DASH', 'BCH'), ('DASH', 'LINK'), ('DASH', 'LTC'), ('DASH', 'ONT'), ('DASH', 'XLM'), ('DCR', 'BORG'), ('DCR', 'GAS'), ('DCR', 'THETA'), ('DCR', 'XNO'), ('DCR', 'XVG'), ('DENT', 'ARK'), ('DENT', 'BLZ'), ('DENT', 'MED'), ('DENT', 'STEEM'), ('DENT', 'STMX'), ('DGB', 'BCH'), ('DGB', 'DASH'), ('DGB', 'NEO'), ('DGB', 'ONT'), ('DGB', 'XVG'), ('DOGE', 'ETC'), ('ENJ', 'BAT'), ('ENJ', 'STORJ'), ('EOS', 'BCH'), ('EOS', 'DASH'), ('EOS', 'NEO'), ('EOS', 'ONT'), ('EOS', 'XVG'), ('ETC', 'DOGE'), ('FUN', 'BORG'), ('FUN', 'SNX'), ('FUN', 'XLM'), ('FUN', 'ZRX'), ('GAS', 'DCR'), ('GAS', 'LSK'), ('GAS', 'RVN'), ('GAS', 'STEEM'), ('GAS', 'THETA'), ('ICX', 'ARK'), ('ICX', 'CVC'), ('ICX', 'IOTA'), ('ICX', 'REN'), ('ICX', 'UTK'), ('IOST', 'ARDR'), ('IOST', 'ARK'), ('IOST', 'CVC'), ('IOST', 'ICX'), ('IOST', 'IOTA'), ('IOTA', 'ARK'), ('IOTA', 'CVC'), ('IOTA', 'ICX'), ('IOTA', 'IOST'), ('IOTA', 'SNT'), ('LINK', 'BCH'), ('LINK', 'DASH'), ('LINK', 'LTC'), ('LINK', 'XLM'), ('LINK', 'XNO'), ('LSK', 'DASH'), ('LSK', 'ONT'), ('LSK', 'SNT'), ('LSK', 'STEEM'), ('LSK', 'XVG'), ('LTC', 'BCH'), ('LTC', 'DASH'), ('LTC', 'LINK'), ('LTC', 'XLM'), ('LTC', 'XVG'), ('MED', 'DENT'), ('MED', 'MTL'), ('MED', 'STEEM'), ('MED', 'STMX'), ('MKR', 'XNO'), ('MKR', 'ZEN'), ('MTL', 'ARDR'), ('MTL', 'ARK'), ('MTL', 'MED'), ('MTL', 'STEEM'), ('NEO', 'BCH'), ('NEO', 'DASH'), ('NEO', 'DGB'), ('NEO', 'ONT'), ('NEO', 'XVG'), ('NMR', 'DASH'), ('NMR', 'DGB'), ('NMR', 'NEO'), ('NMR', 'ONT'), ('NMR', 'XVG'), ('NULS', 'ADX'), ('NULS', 'BLZ'), ('NULS', 'IOTA'), ('NULS', 'SNT'), ('NULS', 'UTK'), ('ONT', 'DASH'), ('ONT', 'DGB'), ('ONT', 'LSK'), ('ONT', 'SNT'), ('ONT', 'XVG'), ('PIVX', 'ADX'), ('PIVX', 'DGB'), ('PIVX', 'NMR'), ('PIVX', 'ONT'), ('PIVX', 'XVG'), ('QTUM', 'ARDR'), ('QTUM', 'BTG'), ('QTUM', 'STRAX'), ('QTUM', 'XRP'), ('QTUM', 'ZEN'), ('REN', 'ICX'), ('RVN', 'GAS'), ('RVN', 'IOTA'), ('RVN', 'UTK'), ('SBD', 'ARK'), ('SBD', 'DCR'), ('SBD', 'GAS'), ('SBD', 'THETA'), ('SNT', 'LSK'), ('SNT', 'ONT'), ('SNT', 'STEEM'), ('SNT', 'XVG'), ('SNT', 'ZRX'), ('SNX', 'FUN'), ('STEEM', 'ARK'), ('STEEM', 'LSK'), ('STEEM', 'MED'), ('STEEM', 'SNT'), ('STEEM', 'STMX'), ('STMX', 'ARK'), ('STMX', 'DENT'), ('STMX', 'MED'), ('STMX', 'STEEM'), ('STMX', 'THETA'), ('STORJ', 'BAT'), ('STORJ', 'ENJ'), ('STRAX', 'ARDR'), ('STRAX', 'BTG'), ('STRAX', 'LSK'), ('STRAX', 'QTUM'), ('STRAX', 'ZEN'), ('THETA', 'DCR'), ('THETA', 'GAS'), ('THETA', 'LSK'), ('THETA', 'STMX'), ('THETA', 'XVG'), ('UTK', 'BLZ'), ('UTK', 'DASH'), ('UTK', 'ICX'), ('UTK', 'IOTA'), ('UTK', 'ZRX'), ('XDC', 'ADA'), ('XLM', 'DASH'), ('XLM', 'LINK'), ('XLM', 'LTC'), ('XLM', 'XNO'), ('XLM', 'ZRX'), ('XMR', 'BTG'), ('XMR', 'NEO'), ('XNO', 'BCH'), ('XNO', 'DCR'), ('XNO', 'NEO'), ('XNO', 'XLM'), ('XNO', 'XVG'), ('XRP', 'BTG'), ('XRP', 'QTUM'), ('XVG', 'DGB'), ('XVG', 'LSK'), ('XVG', 'NEO'), ('XVG', 'ONT'), ('XVG', 'SNT'), ('ZEN', 'BTG'), ('ZEN', 'MKR'), ('ZEN', 'QTUM'), ('ZEN', 'STRAX'), ('ZEN', 'XNO'), ('ZIL', 'SNT'), ('ZIL', 'ZRX'), ('ZRX', 'DASH'), ('ZRX', 'FUN'), ('ZRX', 'SNT'), ('ZRX', 'UTK'), ('ZRX', 'XLM')]
# Number of pairs to be traded: 229
# Pairs Updated date: 2023-01-01
# ...
# Number of pairs to be traded: 331
# Pairs Updated date: 2023-10-01
# Final pairs to be traded: [('ADA', 'DCR'), ('ADA', 'EOS'), ('ADA', 'IOST'), ('ADA', 'MLN'), ('ADA', 'STRAX'), ('ADX', 'ARK'), ('ADX', 'IOTA'), ('ADX', 'ONT'), ('ADX', 'THETA'), ('ADX', 'XEM'), ('AMB', 'PIVX'), ('AMB', 'RLC'), ('AMB', 'RVN'), ('ARDR', 'CVC'), ('ARDR', 'MED'), ('ARDR', 'SNT'), ('ARDR', 'STMX'), ('ARDR', 'XEM'), ('ARK', 'ARDR'), ('ARK', 'ONT'), ('ARK', 'SNT'), ('ARK', 'STMX'), ('ARK', 'XEM'), ('BAT', 'ENJ'), ('BAT', 'GNO'), ('BAT', 'MANA'), ('BAT', 'STORJ'), ('BAT', 'VGX'), ('BCH', 'BTC'), ('BCH', 'XLM'), ('BCH', 'XNO'), ('BCH', 'XRP'), ('BCH', 'XVG'), ('BLZ', 'ARK'), ('BLZ', 'MKR'), ('BLZ', 'QTUM'), ('BLZ', 'STMX'), ('BLZ', 'ZEN'), ('BNB', 'ADX'), ('BNB', 'DASH'), ('BNB', 'ENJ'), ('BNB', 'ONT'), ('BNB', 'VGX'), ('BORG', 'IOTA'), ('BORG', 'MED'), ('BORG', 'UTK'), ('BORG', 'VGX'), ('BORG', 'XEM'), ('BTC', 'BCH'), ('BTC', 'NEO'), ('BTC', 'ONT'), ('BTC', 'XLM'), ('BTC', 'XRP'), ('BTG', 'ADA'), ('BTG', 'DCR'), ('BTG', 'EOS'), ('BTG', 'IOST'), ('BTG', 'STMX'), ('CVC', 'ARDR'), ('CVC', 'MED'), ('CVC', 'ONT'), ('CVC', 'SNT'), ('CVC', 'STMX'), ('DASH', 'DENT'), ('DASH', 'DGB'), ('DASH', 'EOS'), ('DASH', 'ONT'), ('DASH', 'XEM'), ('DCR', 'ADA'), ('DCR', 'ARDR'), ('DCR', 'CVC'), ('DCR', 'EOS'), ('DCR', 'IOST'), ('DENT', 'DGB'), ('DENT', 'NEO'), ('DENT', 'ONT'), ('DENT', 'THETA'), ('DENT', 'XNO'), ('DGB', 'DENT'), ('DGB', 'ONT'), ('DGB', 'QTUM'), ('DGB', 'THETA'), ('DGB', 'XNO'), ('DOGE', 'DENT'), ('DOGE', 'DGB'), ('DOGE', 'MLN'), ('DOGE', 'THETA'), ('DOGE', 'XNO'), ('ENJ', 'ADX'), ('ENJ', 'BAT'), ('ENJ', 'STORJ'), ('ENJ', 'VGX'), ('ENJ', 'WAXP'), ('EOS', 'ADA'), ('EOS', 'DCR'), ('EOS', 'DGB'), ('EOS', 'ONT'), ('EOS', 'XEM'), ('ETC', 'BTG'), ('ETC', 'EOS'), ('ETC', 'SNX'), ('FUN', 'BTG'), ('FUN', 'CVC'), ('FUN', 'DCR'), ('FUN', 'EOS'), ('FUN', 'REN'), ('GAS', 'DENT'), ('GAS', 'NEO'), ('GAS', 'ONT'), ('GAS', 'SBD'), ('GAS', 'STRAX'), ('GLM', 'ARDR'), ('GLM', 'CVC'), ('GLM', 'LSK'), ('GLM', 'MED'), ('GLM', 'SNT'), ('GNO', 'ADX'), ('GNO', 'BAT'), ('GNO', 'ENJ'), ('GNO', 'IOTA'), ('GNO', 'ZEC'), ('ICX', 'DENT'), ('ICX', 'DGB'), ('ICX', 'NEO'), ('ICX', 'QTUM'), ('ICX', 'XNO'), ('IDEX', 'CVC'), ('IDEX', 'IOTA'), ('IDEX', 'MED'), ('IDEX', 'ONT'), ('IDEX', 'ZEN'), ('IOST', 'ADA'), ('IOST', 'ARDR'), ('IOST', 'DCR'), ('IOST', 'EOS'), ('IOST', 'STMX'), ('IOTA', 'MED'), ('IOTA', 'RVN'), ('IOTA', 'THETA'), ('IOTA', 'UTK'), ('IOTA', 'XEM'), ('LINK', 'DENT'), ('LINK', 'RVN'), ('LINK', 'THETA'), ('LINK', 'XEM'), ('LINK', 'XNO'), ('LRC', 'BAT'), ('LRC', 'ENJ'), ('LRC', 'MANA'), ('LRC', 'WAXP'), ('LSK', 'ARDR'), ('LSK', 'MED'), ('LSK', 'ONT'), ('LSK', 'SNT'), ('LSK', 'STMX'), ('LTC', 'DASH'), ('LTC', 'DENT'), ('LTC', 'NEO'), ('LTC', 'RLC'), ('LTC', 'XVG'), ('MANA', 'BAT'), ('MANA', 'ENJ'), ('MANA', 'POWR'), ('MANA', 'STORJ'), ('MANA', 'WAXP'), ('MED', 'ARDR'), ('MED', 'CVC'), ('MED', 'LSK'), ('MED', 'SNT'), ('MED', 'XEM'), ('MKR', 'ARK'), ('MKR', 'BCH'), ('MKR', 'IOTA'), ('MKR', 'SNT'), ('MKR', 'XLM'), ('MLN', 'ADA'), ('MLN', 'DENT'), ('MLN', 'ICX'), ('MLN', 'REN'), ('MLN', 'XNO'), ('MTL', 'GAS'), ('MTL', 'NEO'), ('MTL', 'SNX'), ('MTL', 'STEEM'), ('MTL', 'STMX'), ('NEO', 'DENT'), ('NEO', 'DGB'), ('NEO', 'GAS'), ('NEO', 'ICX'), ('NEO', 'ONT'), ('NMR', 'EOS'), ('NMR', 'GAS'), ('NMR', 'NEO'), ('NMR', 'ONT'), ('NMR', 'SBD'), ('NULS', 'BAT'), ('NULS', 'GNO'), ('NULS', 'IOTA'), ('OMG', 'ADA'), ('OMG', 'DENT'), ('OMG', 'MLN'), ('OMG', 'NEO'), ('OMG', 'REN'), ('ONT', 'DENT'), ('ONT', 'DGB'), ('ONT', 'QTUM'), ('ONT', 'THETA'), ('ONT', 'XEM'), ('PIVX', 'AMB'), ('PIVX', 'RLC'), ('POWR', 'BAT'), ('POWR', 'MANA'), ('POWR', 'SYS'), ('QTUM', 'DENT'), ('QTUM', 'DGB'), ('QTUM', 'ONT'), ('QTUM', 'THETA'), ('QTUM', 'XNO'), ('REN', 'ADA'), ('REN', 'ICX'), ('REN', 'MLN'), ('REN', 'STRAX'), ('REN', 'XNO'), ('REQ', 'BAT'), ('REQ', 'STORJ'), ('RLC', 'DASH'), ('RLC', 'DENT'), ('RLC', 'GAS'), ('RLC', 'LTC'), ('RLC', 'XNO'), ('RVN', 'EOS'), ('RVN', 'IOTA'), ('RVN', 'LINK'), ('RVN', 'THETA'), ('RVN', 'XEM'), ('SBD', 'ARDR'), ('SBD', 'GAS'), ('SBD', 'LSK'), ('SBD', 'ONT' ...
# Number of pairs to be traded: 341
# Pairs Updated date: 2024-01-01
# Final pairs to be traded: [('ADA', 'DENT'), ('ADA', 'IOTA'), ('ADA', 'THETA'), ('ADA', 'WAXP'), ('ADA', 'XNO'), ('ADX', 'DENT'), ('ADX', 'ENJ'), ('ADX', 'ONT'), ('ADX', 'WAXP'), ('ADX', 'XEM'), ('ARDR', 'CVC'), ('ARDR', 'IOST'), ('ARDR', 'ONT'), ('ARDR', 'QTUM'), ('ARDR', 'XEM'), ('ARK', 'SBD'), ('BAT', 'ENJ'), ('BAT', 'IOTA'), ('BAT', 'MLN'), ('BAT', 'WAXP'), ('BAT', 'ZEN'), ('BCH', 'MKR'), ('BNB', 'DASH'), ('BNB', 'DENT'), ('BNB', 'EOS'), ('BNB', 'REQ'), ('BNB', 'UTK'), ('BORG', 'ADX'), ('BORG', 'ENJ'), ('BORG', 'MANA'), ('BORG', 'WAXP'), ('BORG', 'XEM'), ('BTG', 'ARDR'), ('BTG', 'CVC'), ('BTG', 'IOST'), ('BTG', 'QTUM'), ('BTG', 'ZEN'), ('CVC', 'ARDR'), ('CVC', 'IOST'), ('CVC', 'MED'), ('CVC', 'XEM'), ('CVC', 'ZEN'), ('DASH', 'DENT'), ('DASH', 'DGB'), ('DASH', 'EOS'), ('DASH', 'MLN'), ('DASH', 'OMG'), ('DCR', 'CVC'), ('DCR', 'EOS'), ('DCR', 'MED'), ('DCR', 'OMG'), ('DCR', 'XEM'), ('DENT', 'ADX'), ('DENT', 'ICX'), ('DENT', 'ONT'), ('DENT', 'THETA'), ('DENT', 'XNO'), ('DGB', 'DENT'), ('DGB', 'ICX'), ('DGB', 'ONT'), ('DGB', 'REN'), ('DGB', 'THETA'), ('DOGE', 'ADX'), ('DOGE', 'BORG'), ('DOGE', 'DENT'), ('DOGE', 'THETA'), ('DOGE', 'XNO'), ('ENJ', 'BAT'), ('ENJ', 'IOTA'), ('ENJ', 'MLN'), ('ENJ', 'THETA'), ('ENJ', 'WAXP'), ('EOS', 'DCR'), ('EOS', 'MED'), ('EOS', 'OMG'), ('EOS', 'REN'), ('EOS', 'XEM'), ('FUN', 'DCR'), ('FUN', 'EOS'), ('FUN', 'MED'), ('FUN', 'OMG'), ('FUN', 'UTK'), ('GLM', 'ARDR'), ('GLM', 'CVC'), ('GLM', 'LSK'), ('GLM', 'ONT'), ('GLM', 'XEM'), ('GNO', 'ICX'), ('GNO', 'ONT'), ('GNO', 'QTUM'), ('GNO', 'STMX'), ('GNO', 'ZRX'), ('ICX', 'DENT'), ('ICX', 'ONT'), ('ICX', 'QTUM'), ('ICX', 'WAXP'), ('ICX', 'ZEN'), ('IDEX', 'ADX'), ('IDEX', 'ENJ'), ('IDEX', 'ICX'), ('IDEX', 'IOTA'), ('IDEX', 'WAXP'), ('IOST', 'ARDR'), ('IOST', 'CVC'), ('IOST', 'DGB'), ('IOST', 'MED'), ('IOST', 'OMG'), ('IOTA', 'BAT'), ('IOTA', 'ENJ'), ('IOTA', 'THETA'), ('IOTA', 'WAXP'), ('IOTA', 'ZEN'), ('LINK', 'STRAX'), ('LRC', 'BAT'), ('LRC', 'ENJ'), ('LRC', 'MLN'), ('LRC', 'REQ'), ('LRC', 'XNO'), ('LSK', 'ARDR'), ('LSK', 'CVC'), ('LSK', 'ONT'), ('LSK', 'QTUM'), ('LSK', 'STMX'), ('MANA', 'BAT'), ('MANA', 'ENJ'), ('MANA', 'THETA'), ('MANA', 'WAXP'), ('MANA', 'XEM'), ('MED', 'CVC'), ('MED', 'DCR'), ('MED', 'IOST'), ('MED', 'OMG'), ('MED', 'XEM'), ('MKR', 'BCH'), ('MKR', 'XLM'), ('MLN', 'BAT'), ('MLN', 'ENJ'), ('MLN', 'REQ'), ('MLN', 'WAXP'), ('MLN', 'ZEN'), ('NEO', 'ADX'), ('NEO', 'DENT'), ('NEO', 'ICX'), ('NEO', 'ONT'), ('NEO', 'QTUM'), ('NMR', 'NEO'), ('NMR', 'ONT'), ('NULS', 'DENT'), ('NULS', 'LRC'), ('NULS', 'MLN'), ('NULS', 'THETA'), ('NULS', 'XNO'), ('OMG', 'DCR'), ('OMG', 'EOS'), ('OMG', 'MED'), ('OMG', 'REN'), ('OMG', 'XEM'), ('ONT', 'DENT'), ('ONT', 'ICX'), ('ONT', 'QTUM'), ('ONT', 'THETA'), ('ONT', 'XEM'), ('POWR', 'ADA'), ('POWR', 'ARDR'), ('POWR', 'NEO'), ('POWR', 'ONT'), ('POWR', 'XEM'), ('PRO', 'ADA'), ('PRO', 'DCR'), ('PRO', 'MANA'), ('PRO', 'OMG'), ('PRO', 'XEM'), ('QTUM', 'ARDR'), ('QTUM', 'DENT'), ('QTUM', 'ICX'), ('QTUM', 'ONT'), ('QTUM', 'XEM'), ('REN', 'MLN'), ('REN', 'THETA'), ('REN', 'WAXP'), ('REN', 'XEM'), ('REN', 'ZEN'), ('REQ', 'BAT'), ('REQ', 'ENJ'), ('REQ', 'MLN'), ('REQ', 'THETA'), ('REQ', 'WAXP'), ('RVN', 'BAT'), ('RVN', 'ENJ'), ('RVN', 'IOTA'), ('RVN', 'REQ'), ('RVN', 'VGX'), ('SBD', 'ARK'), ('SBD', 'STRAX'), ('SNT', 'ARDR'), ('SNT', 'LSK'), ('SNT', 'POWR'), ('SNT', 'STMX'), ('SNT', 'ZRX'), ('SNX', 'GNO'), ('SNX', 'POWR'), ('SNX', 'QTUM'), ('SNX', 'STMX'), ('SNX', 'ZRX'), ('STEEM', 'ARDR'), ('STEEM', 'CVC'), ('STEEM', 'LSK'), ('STEEM', 'STMX'), ('STEEM', 'ZRX'), ('STMX', 'ARDR'), ('STMX', 'CVC'), ('STMX', 'LSK'), ('STMX', 'QTUM'), ('STMX', 'ZRX'), ('STORJ', 'ADA'), ('STORJ', 'BAT'), ('STORJ', 'GNO'), ('STORJ', 'POWR'), ('STORJ', 'STMX'), ('STRAX', 'LINK'), ('STRAX', 'SBD'), ('STRAX', 'STORJ'), ('SYS', 'ENJ'), ('SYS', 'IOTA'), ('SYS', 'MLN'), ('SYS', 'WAXP'), ('SYS', 'XNO'), ('THETA', 'DENT'), ('THETA', 'ENJ'), ('THETA', 'ONT'), ('THETA', 'WAXP'), ('THETA', 'XEM'), ('TRAC', 'NULS'), ('UTK', 'BAT'), ('UTK', 'MED'), ('UTK', 'OMG ...
# Number of pairs to be traded: 284
# Pairs Updated date: 2024-04-01
# Final pairs to be traded: [('ADA', 'DENT'), ('ADA', 'IOTA'), ('ADA', 'ONT'), ('ADA', 'QTUM'), ('ADA', 'XNO'), ('ADX', 'DENT'), ('ADX', 'ONT'), ('ADX', 'QTUM'), ('ADX', 'SYS'), ('ADX', 'XNO'), ('ANT', 'BTC'), ('ANT', 'ELF'), ('ARDR', 'CVC'), ('ARDR', 'IOTA'), ('ARDR', 'ONT'), ('ARDR', 'WAXP'), ('ARDR', 'XEM'), ('BAT', 'ENJ'), ('BAT', 'IOST'), ('BAT', 'MANA'), ('BAT', 'WAXP'), ('BAT', 'ZEN'), ('BLZ', 'LINK'), ('BTC', 'ANT'), ('BTC', 'LINK'), ('BTC', 'TRAC'), ('CVC', 'ARDR'), ('CVC', 'BAT'), ('CVC', 'WAXP'), ('CVC', 'XEM'), ('CVC', 'ZEN'), ('DASH', 'EOS'), ('DASH', 'LRC'), ('DASH', 'MED'), ('DASH', 'MLN'), ('DASH', 'OMG'), ('DCR', 'MED'), ('DCR', 'MLN'), ('DCR', 'OMG'), ('DCR', 'UTK'), ('DCR', 'ZEN'), ('DENT', 'ADX'), ('DENT', 'ONT'), ('DENT', 'QTUM'), ('DENT', 'THETA'), ('DENT', 'XNO'), ('DGB', 'ENJ'), ('DGB', 'IOTA'), ('DGB', 'ONT'), ('DGB', 'SYS'), ('DGB', 'XEM'), ('ELF', 'ANT'), ('ENJ', 'IOST'), ('ENJ', 'LRC'), ('ENJ', 'MANA'), ('ENJ', 'WAXP'), ('ENJ', 'ZIL'), ('EOS', 'DCR'), ('EOS', 'ENJ'), ('EOS', 'MED'), ('EOS', 'OMG'), ('EOS', 'REN'), ('FUN', 'MED'), ('FUN', 'OMG'), ('FUN', 'UTK'), ('GLM', 'THETA'), ('GNO', 'LSK'), ('ICX', 'ENJ'), ('ICX', 'IOST'), ('ICX', 'WAXP'), ('ICX', 'XEM'), ('ICX', 'ZIL'), ('IDEX', 'ICX'), ('IDEX', 'ONT'), ('IOST', 'ENJ'), ('IOST', 'MANA'), ('IOST', 'WAXP'), ('IOST', 'ZEN'), ('IOST', 'ZIL'), ('IOTA', 'ARDR'), ('IOTA', 'DGB'), ('IOTA', 'ENJ'), ('IOTA', 'WAXP'), ('IOTA', 'XEM'), ('LINK', 'BLZ'), ('LINK', 'BTC'), ('LRC', 'ENJ'), ('LRC', 'IOST'), ('LRC', 'MANA'), ('LRC', 'MED'), ('LRC', 'ZIL'), ('LSK', 'DENT'), ('LSK', 'ONT'), ('LSK', 'QTUM'), ('LSK', 'THETA'), ('LSK', 'XNO'), ('MANA', 'BAT'), ('MANA', 'ENJ'), ('MANA', 'IOST'), ('MANA', 'WAXP'), ('MANA', 'ZIL'), ('MED', 'IOST'), ('MED', 'MANA'), ('MED', 'OMG'), ('MED', 'REN'), ('MED', 'ZEN'), ('MLN', 'ENJ'), ('MLN', 'LRC'), ('MLN', 'MED'), ('MLN', 'REN'), ('MLN', 'WAXP'), ('NEO', 'DENT'), ('NEO', 'LSK'), ('NEO', 'ONT'), ('NEO', 'QTUM'), ('NEO', 'XNO'), ('NMR', 'RLC'), ('OMG', 'DCR'), ('OMG', 'MANA'), ('OMG', 'MED'), ('OMG', 'REN'), ('OMG', 'ZEC'), ('ONT', 'ADX'), ('ONT', 'ARDR'), ('ONT', 'DENT'), ('ONT', 'QTUM'), ('ONT', 'XEM'), ('PRO', 'CVC'), ('QTUM', 'ADX'), ('QTUM', 'ARDR'), ('QTUM', 'DENT'), ('QTUM', 'ONT'), ('QTUM', 'XEM'), ('REN', 'ENJ'), ('REN', 'IOST'), ('REN', 'WAXP'), ('REN', 'ZEN'), ('REN', 'ZIL'), ('REQ', 'DGB'), ('REQ', 'ENJ'), ('REQ', 'IOTA'), ('REQ', 'SYS'), ('REQ', 'XEM'), ('RLC', 'NMR'), ('RLC', 'TRAC'), ('RVN', 'EOS'), ('SNT', 'LSK'), ('SNT', 'NEO'), ('SNT', 'STMX'), ('SNX', 'ADA'), ('SNX', 'NEO'), ('STEEM', 'ARDR'), ('STEEM', 'ONT'), ('STEEM', 'QTUM'), ('STMX', 'ARDR'), ('STMX', 'IOTA'), ('STMX', 'ONT'), ('STMX', 'QTUM'), ('STMX', 'XEM'), ('SYS', 'ADX'), ('SYS', 'DGB'), ('SYS', 'ENJ'), ('SYS', 'ONT'), ('SYS', 'XEM'), ('THETA', 'DENT'), ('THETA', 'GLM'), ('THETA', 'LSK'), ('THETA', 'ONT'), ('THETA', 'XNO'), ('TRAC', 'BTC'), ('TRAC', 'RLC'), ('UTK', 'BAT'), ('UTK', 'DCR'), ('UTK', 'LRC'), ('UTK', 'MED'), ('UTK', 'OMG'), ('VGX', 'DCR'), ('VGX', 'EOS'), ('VGX', 'MED'), ('VGX', 'OMG'), ('VGX', 'ZEC'), ('WAVES', 'ENJ'), ('WAVES', 'IOST'), ('WAVES', 'REN'), ('WAVES', 'WAXP'), ('WAVES', 'ZIL'), ('WAXP', 'ENJ'), ('WAXP', 'IOST'), ('WAXP', 'MANA'), ('WAXP', 'ZEN'), ('WAXP', 'ZIL'), ('XEM', 'ARDR'), ('XEM', 'DGB'), ('XEM', 'ENJ'), ('XEM', 'IOTA'), ('XEM', 'WAXP'), ('XNO', 'ADA'), ('XNO', 'ADX'), ('XNO', 'DENT'), ('XNO', 'LSK'), ('XNO', 'ONT'), ('ZEC', 'DCR'), ('ZEC', 'IOST'), ('ZEC', 'MED'), ('ZEC', 'OMG'), ('ZEC', 'ZEN'), ('ZEN', 'BAT'), ('ZEN', 'ENJ'), ('ZEN', 'IOST'), ('ZEN', 'WAXP'), ('ZEN', 'ZIL'), ('ZIL', 'ENJ'), ('ZIL', 'IOST'), ('ZIL', 'MANA'), ('ZIL', 'REN'), ('ZIL', 'WAXP')]
# Number of pairs to be traded: 216
# Pairs Updated date: 2024-07-01
# Final pairs to be traded: [('ADX', 'DENT'), ('ANT', 'BCH'), ('ANT', 'BTC'), ('ANT', 'MKR'), ('ANT', 'TRX'), ('ARK', 'GAS'), ('BAT', 'ENJ'), ('BAT', 'IOST'), ('BAT', 'MANA'), ('BAT', 'WAXP'), ('BAT', 'ZIL'), ('BCH', 'ANT'), ('BCH', 'BTC'), ('BCH', 'MKR'), ('BLZ', 'LINK'), ('BLZ', 'TRX'), ('BNB', 'DOGE'), ('BNB', 'SWFTC'), ('BTC', 'ANT'), ('BTC', 'BCH'), ('BTC', 'GNO'), ('BTC', 'MKR'), ('BTC', 'TRAC'), ('BTG', 'GLM'), ('BTG', 'THETA'), ('DENT', 'ADX'), ('DENT', 'NMR'), ('DENT', 'QTUM'), ('DENT', 'THETA'), ('DENT', 'XNO'), ('DGB', 'SYS'), ('DOGE', 'BNB'), ('ELF', 'TRX'), ('ENJ', 'BAT'), ('ENJ', 'IOST'), ('ENJ', 'MANA'), ('ENJ', 'WAXP'), ('ENJ', 'ZIL'), ('EOS', 'MED'), ('FUN', 'OMG'), ('GAS', 'ARK'), ('GLM', 'BTG'), ('GLM', 'THETA'), ('GNO', 'BTC'), ('GNO', 'TRAC'), ('IOST', 'BAT'), ('IOST', 'ENJ'), ('IOST', 'MANA'), ('IOST', 'WAXP'), ('IOST', 'ZIL'), ('LINK', 'BLZ'), ('LINK', 'TRX'), ('LRC', 'ENJ'), ('LRC', 'ZIL'), ('LSK', 'DENT'), ('LSK', 'NMR'), ('LSK', 'ONT'), ('LSK', 'THETA'), ('MANA', 'BAT'), ('MANA', 'ENJ'), ('MANA', 'IOST'), ('MANA', 'WAXP'), ('MANA', 'ZIL'), ('MED', 'ENJ'), ('MED', 'MANA'), ('MED', 'OMG'), ('MED', 'REN'), ('MED', 'ZIL'), ('MKR', 'ANT'), ('MKR', 'BCH'), ('MKR', 'BTC'), ('NEO', 'ONT'), ('NMR', 'DENT'), ('NMR', 'LSK'), ('NMR', 'RLC'), ('NMR', 'XNO'), ('NULS', 'PRO'), ('OMG', 'FUN'), ('OMG', 'MED'), ('OMG', 'REN'), ('OMG', 'ZEC'), ('ONT', 'LSK'), ('ONT', 'NEO'), ('ONT', 'QTUM'), ('PRO', 'NULS'), ('QTUM', 'DENT'), ('QTUM', 'ONT'), ('QTUM', 'STEEM'), ('REN', 'MANA'), ('REN', 'MED'), ('REN', 'OMG'), ('REN', 'UTK'), ('REN', 'ZIL'), ('RLC', 'NMR'), ('RLC', 'TRAC'), ('SBD', 'SNT'), ('SNT', 'SBD'), ('STEEM', 'QTUM'), ('SWFTC', 'BNB'), ('SWFTC', 'THETA'), ('SYS', 'DGB'), ('THETA', 'BTG'), ('THETA', 'DENT'), ('THETA', 'GLM'), ('THETA', 'LSK'), ('THETA', 'SWFTC'), ('TRAC', 'BTC'), ('TRAC', 'GNO'), ('TRAC', 'RLC'), ('TRX', 'ANT'), ('TRX', 'BLZ'), ('TRX', 'BTC'), ('TRX', 'ELF'), ('TRX', 'LINK'), ('UTK', 'ENJ'), ('UTK', 'MED'), ('UTK', 'REN'), ('UTK', 'ZIL'), ('WAVES', 'BAT'), ('WAVES', 'IOST'), ('WAVES', 'WAXP'), ('WAVES', 'ZEN'), ('WAVES', 'ZIL'), ('WAXP', 'BAT'), ('WAXP', 'ENJ'), ('WAXP', 'IOST'), ('WAXP', 'MANA'), ('WAXP', 'ZIL'), ('XNO', 'DENT'), ('XNO', 'NMR'), ('ZEC', 'OMG'), ('ZEN', 'BAT'), ('ZEN', 'IOST'), ('ZEN', 'WAVES'), ('ZEN', 'WAXP'), ('ZEN', 'ZIL'), ('ZIL', 'BAT'), ('ZIL', 'ENJ'), ('ZIL', 'IOST'), ('ZIL', 'MANA'), ('ZIL', 'WAXP')]
# Number of pairs to be traded: 141

# %%
print(metrics_df)
# Out:
#      Sharpe Ratio    Return  Volatility  Holding Period  Turnover  \
# 0.1      1.566602  0.001296    0.013131        8.785549  0.227647
# 0.2      1.508085  0.001336    0.014058        8.279351  0.241565
# 0.5      1.358545  0.001370    0.016012        8.102245  0.246845
# 0.7      1.333609  0.001484    0.017663        8.315641  0.240511
#
#      Transaction Costs
# 0.1           0.770356
# 0.2           0.817455
# 0.5           0.835324
# 0.7           0.813888

# %% [markdown]
# The performance across different thresholds is relatively robust, with only minor variations. Interestingly, the correlation-based method appears to outperform the cointegration approach

# %%
strat_net_ret = strat_net_ret_dict[0.1]
strat_net_ret.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# The major drawback is that the performance has been steady during 2022-2024, even though the pairs are updated frequently.
#
# We also compare the performance of our strategy against our benchmark, specifically a buy-and-hold strategy for Bitcoin. We will evaluate key metrics including alpha and beta, maximum drawdowns and maximum drawdown duration.

# %%
buy_and_hold_btc = coins_ret['BTC'][start_of_out_sample:]
buy_and_hold_btc
# Out:
# Date
# 2020-01-01   -0.006253
# 2020-01-02   -0.000194
# 2020-01-03   -0.031958
# 2020-01-04    0.048320
# 2020-01-05    0.006990
#                 ...
# 2024-08-12   -0.034218
# 2024-08-13    0.009282
# 2024-08-14    0.021081
# 2024-08-15   -0.030726
# 2024-08-16   -0.018984
# Name: BTC, Length: 1692, dtype: float64

# %%
full_sample_ret = pd.DataFrame({
    'strat_ret': strat_net_ret,
    'buy_and_hold_btc': buy_and_hold_btc
})

full_sample_stats = compute_stats(full_sample_ret)
print(full_sample_stats)
# Out:
#                        avg       vol    sharpe  hit_rate
# strat_ret         0.326556  0.208449  1.566602  0.524232
# buy_and_hold_btc  0.439585  0.535531  0.820839  0.513626

# %%
full_sample_ret.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
corr = full_sample_ret.rolling(252).corr(full_sample_ret['buy_and_hold_btc'])
vol = full_sample_ret.rolling(252).std()

beta = (corr*vol).divide(vol['buy_and_hold_btc'], 0)

# Computing Point-in-Time Residual Returns
resid = full_sample_ret - beta.multiply(full_sample_ret['buy_and_hold_btc'], axis=0)
print(resid)
print(resid.corr())

# The information ratio
IR = resid.mean()/resid.std()*np.sqrt(252)
print(f"Information ratio is {IR['strat_ret']}")
# Out:
#            strat_ret  buy_and_hold_btc
# Date
# 2020-01-01       NaN               NaN
# 2020-01-02       NaN               NaN
# 2020-01-03       NaN               NaN
# 2020-01-04       NaN               NaN
# 2020-01-05       NaN               NaN
# ...              ...               ...
# 2024-08-12 -0.003478      1.457168e-16
# 2024-08-13   0.00932     -3.989864e-17
# 2024-08-14 -0.000546     -9.367507e-17
# 2024-08-15 -0.002998      1.353084e-16
# 2024-08-16  -0.00505      8.326673e-17
#
# [1692 rows x 2 columns]
#                   strat_ret  buy_and_hold_btc
# strat_ret          1.000000          0.028531
# buy_and_hold_btc   0.028531          1.000000
# Information ratio is 1.2531577620603185

# %% [markdown]
# Note: in practice we have to estimate the beta using rolling windows rather than the full sample

# %% [markdown]
# The correlation of the residual returns with Bitcoin is 0.0285, suggesting that the strategy captures true alpha

# %%
# Plot drawdown
# dd = drawdown(full_sample_ret['strat_ret'].cumsum())
dd = drawdown(full_sample_ret['strat_ret']) * 100
plt.figure(figsize=(10, 2))
dd.plot()
plt.ylim(-25, 0)
plt.title('Drawdown')
plt.xlabel('Date')
plt.ylabel('Drawdown')
plt.show()
print(f"The max drawdown is {dd.min()}")
# Out:
# The max drawdown is -20.345958113077792

# %%
ddd = duration(full_sample_ret.cumsum())
ddd
# Out:
#            strat_ret buy_and_hold_btc
# Date
# 2020-01-01         0                0
# 2020-01-02         0                1
# 2020-01-03         1                2
# 2020-01-04         0                0
# 2020-01-05         1                0
# ...              ...              ...
# 2024-08-12       172               83
# 2024-08-13       173               84
# 2024-08-14       174               85
# 2024-08-15       175               86
# 2024-08-16       176               87
#
# [1692 rows x 2 columns]

# %%
ddd.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# maximum drawdown duration
ddd.max()
# Out:
# strat_ret           271
# buy_and_hold_btc    824
# dtype: object

# %% [markdown]
# **Final Result**

# %%
avg_return = full_sample_stats.loc['strat_ret', 'avg']
volatility = full_sample_stats.loc['strat_ret', 'vol']
sharpe = full_sample_stats.loc['strat_ret', 'sharpe']
hit_rate = full_sample_stats.loc['strat_ret', 'hit_rate']
max_drawdown = dd.min()
max_duration = ddd.max().loc['strat_ret']
holding_period = metrics_df.loc[0.1, 'Holding Period']
information_ratio = IR['strat_ret']

# Calculate strategy stats with formatted percentages and days
stats = final_results(avg_return, volatility, sharpe, hit_rate, max_drawdown, max_duration, holding_period, information_ratio)
print(stats)
# Out:
#                    Correlation
# Return (Ann.)           32.66%
# Volatility (Ann.)       20.84%
# Sharpe Ratio              1.57
# Hit Rate                52.42%
# Max Drawdown           -20.35%
# Max Duration       271.00 days
# Holding Period       8.79 days
# Information Ratio         1.25

# %% [markdown]
# **Conclusion:**
#
# 1. The correlation-based strategy outperforms the cointegration-based strategy.
# 2. Updating pairs every 3 months yields better performance, aligning with the fast-moving crypto market.
# 3. Selecting the top 3 to 5 pairs for each coin works better than choosing just the top pair.

# %%
# Convert 'strat_ret' and 'buy_and_hold_btc' to numeric
full_sample_ret['strat_ret'] = pd.to_numeric(full_sample_ret['strat_ret'], errors='coerce')
full_sample_ret['buy_and_hold_btc'] = pd.to_numeric(full_sample_ret['buy_and_hold_btc'], errors='coerce')

X = full_sample_ret[['buy_and_hold_btc']].fillna(0)
X = sm.add_constant(X)
Y = full_sample_ret['strat_ret'].fillna(0)
# print(X)
# print(Y)

# get params
results = sm.OLS(Y, X).fit()

# %%
# get params
results.params
# Out:
# const               0.001282
# buy_and_hold_btc    0.007763
# dtype: float64

# %%
# get tvalues
results.tvalues
# Out:
# const               4.011311
# buy_and_hold_btc    0.819041
# dtype: float64

# %%
# basically identical
strat_ret = results.params['buy_and_hold_btc']*X['buy_and_hold_btc'] + results.params['const'] + results.resid

(strat_ret-Y).abs().sum()
# Out:
# 1.5338750235238674e-16

# %%
beta_contr = results.params['buy_and_hold_btc']*X['buy_and_hold_btc']
prediction = results.params['buy_and_hold_btc']*X['buy_and_hold_btc'] + results.params['const']
alpha_contr = results.params['const'] + results.resid

alpha_contr
# Out:
# Date
# 2020-01-01   -0.001951
# 2020-01-02    0.002506
# 2020-01-03    0.000225
# 2020-01-04    0.011066
# 2020-01-05   -0.005325
#                 ...
# 2024-08-12   -0.001214
# 2024-08-13    0.008694
# 2024-08-14   -0.002013
# 2024-08-15   -0.000872
# 2024-08-16   -0.003733
# Length: 1692, dtype: float64

# %%
alpha_contr.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# correl is zero to btc
alpha_contr.corr(X['buy_and_hold_btc'])
# Out:
# -3.4785136562741696e-18

# %%
# "alpha"
alpha_contr.mean()
# Out:
# 0.0012823476073480897

# %%
# information ratio
alpha_contr.mean()/alpha_contr.std()*np.sqrt(252)
# Out:
# 1.550578091674745
